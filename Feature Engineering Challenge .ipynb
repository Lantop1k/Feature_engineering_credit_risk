# %% [markdown]
# ### Import Necessary libraries

# %%
import json
import pandas as pd
import numpy as np
from typing import List, Dict, Union
from datetime import datetime

# %% [markdown]
# ### Load the JSON file

# %%
# Load the JSON file
with open("Senior_datascientist_assessment[7591]/Credit_bureau_sample_data.json") as f:
    credit_reports = json.load(f)

# %% [markdown]
# ### Visualize the data in the JSON

# %%
credit_reports
# Out:
# [{'application_id': 97,
#   'data': {'consumerfullcredit': {'subjectlist': {'reference': '12876566',
#      'consumerid': '17628566',
#      'searchoutput': 'XXX '},
#     'accountrating': {'noofotheraccountsbad': '0',
#      'noofotheraccountsgood': '3',
#      'noofretailaccountsbad': '0',
#      'noofretailaccountsgood': '2',
#      'nooftelecomaccountsbad': '0',
#      'noofautoloanaccountsbad': '0',
#      'noofautoloanccountsgood': '0',
#      'noofhomeloanaccountsbad': '0',
#      'nooftelecomaccountsgood': '0',
#      'noofhomeloanaccountsgood': '0',
#      'noofjointloanaccountsbad': '0',
#      'noofstudyloanaccountsbad': '0',
#      'noofcreditcardaccountsbad': '0',
#      'noofjointloanaccountsgood': '0',
#      'noofstudyloanaccountsgood': '0',
#      'noofcreditcardaccountsgood': '1',
#      'noofpersonalloanaccountsbad': '0',
#      'noofpersonalloanaccountsgood': '1'},
#     'enquirydetails': {'productid': '45',
#      'matchingrate': '90',
#      'subscriberenquiryengineid': '5012874225',
#      'subscriberenquiryresultid': '6381470'},
#     'guarantorcount': {'accounts': '0', 'guarantorssecured': '0'},
#     'guarantordetails': {'guarantorgender': None,
#      'guarantorotherid': None,
#      'guarantoraddress1': None,
#      'guarantoraddress2': None,
#      'guarantoraddress3': None,
#      'guarantorpassport': None,
#      'guarantorfirstname': None,
#      'guarantorothername': None,
#      'guarantordateofbirth': '1900-01-01T00:00:00+01:00',
#      'guarantornationalidno': None,
#      'guarantorhometelephone': None,
#      'guarantorworktelephone': None,
#      'guarantordriverlicenceno': None,
#      'guarantormobiletelephone': None},
#     'telephonehistory': [{'homenoupdatedondate': '08/04/2016',
#       'hometelephonenumber': 'XXX',
#       'mobiletelephonenumber': 'XXX'},
#      {'homenoupdatedondate': '18/01/2016',
#       'hometelephonenumber': 'XXX',
#       'mobiletelephonenumber': 'XXX'},
#      {'homenoupdatedondate': '27/08/2015',
#       'hometelephonenumber': 'XXX',
#       'mobiletelephonenumber': 'XXX'}],
#     'employmenthistory': [{'occupation': 'PUBLIC SERVANTS',
#       'updatedate': '16/09/2016',
#       'updateondate': '16/09/2016',
#       'employerdetail': 'ALL MILITARY STAFFS'},
#      {'occupation': 'PUBLIC SERVANTS'},
#      {'occupation': 'PUBLIC SERVANTS'},
#      {'occupation': 'Army Police Defence', 'employerdetail': 'Nigerian navy'},
#      {'occupation': 'PUBLIC SERVANTS'}],
#     'enquiryhistorytop': [{'daterequested': '06/08/2020 18:05:36',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '6050316'},
#      {'daterequested': '01/08/2020 06:59:09',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '5983396'},
#      {'daterequested': '08/07/2020 15:58:44',
#       'enquiryreason': 'application of existing credit by a borrower',
#       'subscribername': 'NewEdge Finance Limited  - transsnet',
#       'subscriberenquiryresultid': '5680296'},
#      {'daterequested': '03/07/2020 22:58:39',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '5637826'},
#      {'daterequested': '04/06/2020 07:55:58',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '5316386'},
#      {'daterequested': '17/04/2020 07:27:02',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '4970915'},
#      {'daterequested': '13/04/2020 00:12:08',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '4938136'},
#      {'daterequested': '28/03/2020 21:54:03',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '4878437'},
#      {'daterequested': '26/03/2020 10:43:57',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '4860495'},
#      {'daterequested': '25/03/2020 04:19:05',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '4846440'},
#      {'daterequested': '25/03/2020 04:17:17',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '4846436'},
#      {'daterequested': '20/03/2020 07:53:56',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '4804544'},
#      {'daterequested': '12/03/2020 09:32:20',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '4709811'},
#      {'daterequested': '28/01/2020 02:39:34',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '4285341'},
#      {'daterequested': '26/01/2020 19:16:17',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '4275291'}],
#     'creditaccountsummary': {'rating': '13',
#      'amountarrear': '24,041.00',
#      'amountarrear1': '0.00',
#      'totalaccounts': '7',
#      'totalaccounts1': '0',
#      'lastjudgementdate': '-',
#      'lastjudgementdate1': '-',
#      'totalaccountarrear': '2',
#      'totalaccountarrear1': '0',
#      'totaljudgementamount': '0',
#      'totaloutstandingdebt': '105,435.00',
#      'totaljudgementamount1': '0',
#      'totaloutstandingdebt1': '0.00',
#      'totaldishonouredamount': '0.00',
#      'totalmonthlyinstalment': '77,404.00',
#      'totalnumberofjudgement': '0',
#      'totaldishonouredamount1': '0.00',
#      'totalmonthlyinstalment1': '0.00',
#      'totalnumberofjudgement1': '0',
#      'totalnumberofdishonoured': '0',
#      'totalnumberofdishonoured1': '0',
#      'totalaccountingodcondition': '0',
#      'totalaccountingodcondition1': '0'},
#     'deliquencyinformation': {'accountno': '2150224012',
#      'periodnum': '20140930',
#      'subscribername': 'First City Monument Bank Ltd Lagos',
#      'monthsinarrears': '13'},
#     'creditagreementsummary': [{'currency': 'NGN',
#       'accountno': '0324562636176001',
#       'closeddate': '01/11/2020',
#       'loanduration': '1170',
#       'subaccountno': None,
#       'accountstatus': 'Open',
#       'amountoverdue': '22,441.39',
#       'subscribername': 'First City Monument Bank Ltd Lagos',
#       'lastupdateddate': '07/08/2020',
#       'instalmentamount': '24,368.39',
#       'currentbalanceamt': '82,733.58',
#       'dateaccountopened': '15/01/2016',
#       'openingbalanceamt': '814,700.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Monthly',
#       'indicatordescription': 'Personal secured loan'},
#      {'currency': 'NGN',
#       'accountno': '0324602636176001',
#       'closeddate': '30/11/2019',
#       'loanduration': '59',
#       'subaccountno': None,
#       'accountstatus': 'Closed',
#       'amountoverdue': '0.00',
#       'subscribername': 'First City Monument Bank Ltd Lagos',
#       'lastupdateddate': '08/08/2017',
#       'instalmentamount': '17,036.09',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '28/08/2014',
#       'openingbalanceamt': '704,000.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Monthly',
#       'indicatordescription': 'Installment account',
#       'currentbalancedebitind': 'C'},
#      {'currency': 'NGN',
#       'accountno': '118908402',
#       'closeddate': '14/10/2019',
#       'loanduration': '31',
#       'subaccountno': None,
#       'accountstatus': 'Open',
#       'amountoverdue': '0.00',
#       'subscribername': 'MyCredit Invest',
#       'lastupdateddate': '20/08/2020',
#       'instalmentamount': '24,000.00',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '13/09/2019',
#       'openingbalanceamt': '20,000.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Monthly',
#       'indicatordescription': 'Personal fixed term loan',
#       'currentbalancedebitind': None},
#      {'currency': 'NGN',
#       'accountno': '1204665',
#       'closeddate': '25/11/2019',
#       'subaccountno': None,
#       'accountstatus': None,
#       'amountoverdue': '0.00',
#       'subscribername': 'MyCredit Invest',
#       'lastupdateddate': '24/12/2019',
#       'instalmentamount': '12,000.00',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '25/10/2019',
#       'openingbalanceamt': '10,000.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Not Available'},
#      {'currency': 'NGN',
#       'accountno': '2150224012',
#       'loanduration': '0',
#       'subaccountno': None,
#       'accountstatus': 'WrittenOff',
#       'amountoverdue': '1,478.37',
#       'subscribername': 'First City Monument Bank Ltd Lagos',
#       'lastupdateddate': '01/03/2018',
#       'currentbalanceamt': '938.00',
#       'dateaccountopened': '09/05/2013',
#       'openingbalanceamt': '0.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Bullet',
#       'indicatordescription': 'Overdraft',
#       'currentbalancedebitind': 'D'},
#      {'currency': 'NGN',
#       'accountno': '2636176011',
#       'loanduration': '0',
#       'subaccountno': None,
#       'accountstatus': None,
#       'amountoverdue': '122.31',
#       'subscribername': 'First City Monument Bank Ltd Lagos',
#       'lastupdateddate': '23/08/2016',
#       'currentbalanceamt': '20,695.64',
#       'dateaccountopened': '12/05/2014',
#       'openingbalanceamt': '0.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Bullet',
#       'indicatordescription': 'Overdraft',
#       'currentbalancedebitind': 'D'},
#      {'currency': 'NGN',
#       'accountno': '2636176028',
#       'closeddate': '21/12/2099',
#       'loanduration': '5843',
#       'subaccountno': None,
#       'accountstatus': 'Open',
#       'amountoverdue': '0.00',
#       'subscribername': 'First City Monument Bank Ltd Lagos',
#       'lastupdateddate': '07/08/2020',
#       'currentbalanceamt': '42,458.57',
#       'dateaccountopened': '20/12/2015',
#       'openingbalanceamt': '50,479.98',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Not Available',
#       'indicatordescription': 'Personal Credit Card Loan'}],
#     'personaldetailssummary': {'gender': 'Male',
#      'header': 'PERSONAL DETAILS SUMMARY: XXX',
#      'surname': 'XXX',
#      'birthdate': '06/05/1991',
#      'firstname': 'XXX',
#      'otheridno': None,
#      'cellularno': 'XXX',
#      'consumerid': '128566',
#      'dependants': '0',
#      'othernames': 'XXX',
#      'pencomidno': None,
#      'nationality': 'Nigeria',
#      'emailaddress': None,
#      'nationalidno': None,
#      'employerdetail': 'ALL MILITARY STAFFS',
#      'postaladdress1': 'XXX ',
#      'postaladdress2': 'KADUNA STATE NIGERIA',
#      'postaladdress3': None,
#      'postaladdress4': {'xml:space': 'preserve', '__content__': ' '},
#      'hometelephoneno': 'XXX',
#      'propertyownedtype': None,
#      'bankverificationno': 'XXX',
#      'residentialaddress1': 'XXX ',
#      'residentialaddress2': 'KADUNA STATE  NIGERIA',
#      'residentialaddress3': None,
#      'residentialaddress4': {'xml:space': 'preserve', '__content__': ' '}},
#     'accountmonthlypaymenthistory': [{'m01': '#',
#       'm02': '3',
#       'm03': '0',
#       'm04': '0',
#       'm05': '0',
#       'm06': '0',
#       'm07': '36',
#       'm08': '36',
#       'm09': '0',
#       'm10': '31',
#       'm11': '0',
#       'm12': '9',
#       'm13': '1',
#       'm14': '0',
#       'm15': '0',
#       'm16': '3',
#       'm17': '5',
#       'm18': '0',
#       'm19': '4',
#       'm20': '4',
#       'm21': '1',
#       'm22': '0',
#       'm23': '4',
#       'm24': '3',
#       'header': 'Details of Credit Agreement with "First City Monument Bank Ltd Lagos" for Account Number: 0324562636176001',
#       'currency': 'NGN',
#       'accountno': '0324562636176001',
#       'tablename': 'Consumer24MonthlyPayment',
#       'closeddate': '01/11/2020',
#       'accountnote': None,
#       'displaytext': 'Consumer 24 Monthly Payment',
#       'loanduration': '1170 Day(s)',
#       'subaccountno': None,
#       'accountstatus': 'Open',
#       'amountoverdue': '22,441.39',
#       'subscribername': 'First City Monument Bank Ltd Lagos',
#       'lastpaymentdate': '01/08/2020',
#       'lastupdateddate': '07/08/2020',
#       'currentbalanceamt': '82,733.58',
#       'dateaccountopened': '15/01/2016',
#       'openingbalanceamt': '814,700.00',
#       'performancestatus': 'Performing',
#       'subscribertypeind': 'C',
#       'indicatordescription': 'Personal secured loan',
#       'monthlyinstalmentamt': '24,368.39',
#       'repaymentfrequencycode': 'Monthly'},
#      {'m01': '#',
#       'm02': '#',
#       'm03': '#',
#       'm04': '#',
#       'm05': '#',
#       'm06': '#',
#       'm07': '#',
#       'm08': '#',
#       'm09': '#',
#       'm10': '#',
#       'm11': '#',
#       'm12': '#',
#       'm13': '#',
#       'm14': '#',
#       'm15': '#',
#       'm16': '#',
#       'm17': '#',
#       'm18': '#',
#       'm19': '#',
#       'm20': '#',
#       'm21': '#',
#       'm22': '#',
#       'm23': '#',
#       'm24': '#',
#       'header': 'Details of Credit Agreement with "First City Monument Bank Ltd Lagos" for Account Number: 0324602636176001',
#       'currency': 'NGN',
#       'accountno': '0324602636176001',
#       'tablename': 'Consumer24MonthlyPayment',
#       'closeddate': '30/11/2019',
#       'accountnote': None,
#       'displaytext': 'Consumer 24 Monthly Payment',
#       'loanduration': '59 Day(s)',
#       'subaccountno': None,
#       'accountstatus': 'Closed',
#       'amountoverdue': '0.00',
#       'subscribername': 'First City Monument Bank Ltd Lagos',
#       'lastpaymentdate': '04/05/2015',
#       'lastupdateddate': '08/08/2017',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '28/08/2014',
#       'openingbalanceamt': '704,000.00',
#       'performancestatus': 'Performing',
#       'subscribertypeind': 'C',
#       'indicatordescription': 'Installment account',
#       'monthlyinstalmentamt': '17,036.09',
#       'currentbalancedebitind': 'C',
#       'repaymentfrequencycode': 'Monthly'},
#      {'m01': '#',
#       'm02': '#',
#       'm03': '#',
#       'm04': '#',
#       'm05': '#',
#       'm06': '#',
#       'm07': '#',
#       'm08': '#',
#       'm09': '#',
#       'm10': '#',
#       'm11': '#',
#       'm12': '#',
#       'm13': '#',
#       'm14': '#',
#       'm15': '#',
#       'm16': '#',
#       'm17': '#',
#       'm18': '#',
#       'm19': '#',
#       'm20': '#',
#       'm21': '#',
#       'm22': '#',
#       'm23': '#',
#       'm24': '#',
#       'header': 'Details of Credit Agreement with "First City Monument Bank Ltd Lagos" for Account Number: 2150224012',
#       'currency': 'NGN',
#       'accountno': '2150224012',
#       'tablename': 'Consumer24MonthlyPayment',
#       'accountnote': None,
#       'displaytext': 'Consumer 24 Monthly Payment',
#       'loanduration': 'Not Available',
#       'subaccountno': None,
#       'accountstatus': 'WrittenOff',
#       'amountoverdue': '1,478.37',
#       'subscribername': 'First City Monument Bank Ltd Lagos',
#       'lastupdateddate': '01/03/2018',
#       'currentbalanceamt': '938.00',
#       'dateaccountopened': '09/05/2013',
#       'openingbalanceamt': '0.00',
#       'performancestatus': 'Performing',
#       'subscribertypeind': 'C',
#       'indicatordescription': 'Overdraft',
#       'currentbalancedebitind': 'D',
#       'repaymentfrequencycode': 'Bullet'},
#      {'m01': '#',
#       'm02': '#',
#       'm03': '#',
#       'm04': '#',
#       'm05': '#',
#       'm06': '#',
#       'm07': '#',
#       'm08': '#',
#       'm09': '#',
#       'm10': '#',
#       'm11': '#',
#       'm12': '#',
#       'm13': '#',
#       'm14': '#',
#       'm15': '#',
#       'm16': '#',
#       'm17': '#',
#       'm18': '#',
#       'm19': '#',
#       'm20': '#',
#       'm21': '#',
#       'm22': '#',
#       'm23': '#',
#       'm24': '#',
#       'header': 'Details of Credit Agreement with "First City Monument Bank Ltd Lagos" for Account Number: 2636176011',
#       'currency': 'NGN',
#       'accountno': '2636176011',
#       'tablename': 'Consumer24MonthlyPayment',
#       'accountnote': None,
#       'displaytext': 'Consumer 24 Monthly Payment',
#       'loanduration': 'Not Available',
#       'subaccountno': None,
#       'accountstatus': None,
#       'amountoverdue': '122.31',
#       'subscribername': 'First City Monument Bank Ltd Lagos',
#       'lastupdateddate': '23/08/2016',
#       'currentbalanceamt': '20,695.64',
#       'dateaccountopened': '12/05/2014',
#       'openingbalanceamt': '0.00',
#       'performancestatus': 'Performing',
#       'subscribertypeind': 'C',
#       'indicatordescription': 'Overdraft',
#       'currentbalancedebitind': 'D',
#       'repaymentfrequencycode': 'Bullet'},
#      {'m01': '#',
#       'm02': '0',
#       'm03': '0',
#       'm04': '0',
#       'm05': '0',
#       'm06': '0',
#       'm07': '0',
#       'm08': '0',
#       'm09': '0',
#       'm10': '0',
#       'm11': '0',
#       'm12': '0',
#       'm13': '0',
#       'm14': '0',
#       'm15': '0',
#       'm16': '0',
#       'm17': '0',
#       'm18': '0',
#       'm19': '0',
#       'm20': '0',
#       'm21': '0',
#       'm22': '0',
#       'm23': '0',
#       'm24': '0',
#       'header': 'Details of Credit Agreement with "First City Monument Bank Ltd Lagos" for Account Number: 2636176028',
#       'currency': 'NGN',
#       'accountno': '2636176028',
#       'tablename': 'Consumer24MonthlyPayment',
#       'closeddate': '21/12/2099',
#       'accountnote': None,
#       'displaytext': 'Consumer 24 Monthly Payment',
#       'loanduration': '5843 Day(s)',
#       'subaccountno': None,
#       'accountstatus': 'Open',
#       'amountoverdue': '0.00',
#       'subscribername': 'First City Monument Bank Ltd Lagos',
#       'lastpaymentdate': '16/07/2020',
#       'lastupdateddate': '07/08/2020',
#       'currentbalanceamt': '42,458.57',
#       'dateaccountopened': '20/12/2015',
#       'openingbalanceamt': '50,479.98',
#       'performancestatus': 'Performing',
#       'subscribertypeind': 'C',
#       'indicatordescription': 'Personal Credit Card Loan',
#       'repaymentfrequencycode': 'Not Available'},
#      {'m01': '#',
#       'm02': '#',
#       'm03': '0',
#       'm04': '#',
#       'm05': '0',
#       'm06': '#',
#       'm07': '#',
#       'm08': '#',
#       'm09': '#',
#       'm10': '#',
#       'm11': '#',
#       'm12': '#',
#       'm13': '#',
#       'm14': '#',
#       'm15': '#',
#       'm16': '#',
#       'm17': '#',
#       'm18': '#',
#       'm19': '#',
#       'm20': '#',
#       'm21': '#',
#       'm22': '#',
#       'm23': '#',
#       'm24': '#',
#       'header': 'Details of Credit Agreement with "MyCredit Invest" for Account Number: 118908402',
#       'currency': 'NGN',
#       'accountno': '118908402',
#       'tablename': 'Consumer24MonthlyPayment',
#       'closeddate': '14/10/2019',
#       'accountnote': None,
#       'displaytext': 'Consumer 24 Monthly Payment',
#       'loanduration': '31 Day(s)',
#       'subaccountno': None,
#       'accountstatus': 'Open',
#       'amountoverdue': '0.00',
#       'subscribername': 'MyCredit Invest',
#       'lastpaymentdate': '23/10/2019',
#       'lastupdateddate': '20/08/2020',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '13/09/2019',
#       'openingbalanceamt': '20,000.00',
#       'performancestatus': 'Performing',
#       'subscribertypeind': 'E',
#       'indicatordescription': 'Personal fixed term loan',
#       'monthlyinstalmentamt': '24,000.00',
#       'currentbalancedebitind': None,
#       'repaymentfrequencycode': 'Monthly'},
#      {'m01': '#',
#       'm02': '#',
#       'm03': '#',
#       'm04': '#',
#       'm05': '#',
#       'm06': '#',
#       'm07': '#',
#       'm08': '#',
#       'm09': '#',
#       'm10': '0',
#       'm11': '#',
#       'm12': '#',
#       'm13': '#',
#       'm14': '#',
#       'm15': '#',
#       'm16': '0',
#       'm17': '#',
#       'm18': '#',
#       'm19': '#',
#       'm20': '#',
#       'm21': '#',
#       'm22': '#',
#       'm23': '#',
#       'm24': '#',
#       'header': 'Details of Credit Agreement with "MyCredit Invest" for Account Number: 1204665',
#       'currency': 'NGN',
#       'accountno': '1204665',
#       'tablename': 'Consumer24MonthlyPayment',
#       'closeddate': '25/11/2019',
#       'accountnote': None,
#       'displaytext': 'Consumer 24 Monthly Payment',
#       'loanduration': 'Not Available',
#       'subaccountno': None,
#       'accountstatus': None,
#       'amountoverdue': '0.00',
#       'subscribername': 'MyCredit Invest',
#       'lastupdateddate': '24/12/2019',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '25/10/2019',
#       'openingbalanceamt': '10,000.00',
#       'performancestatus': 'Performing',
#       'subscribertypeind': 'E',
#       'monthlyinstalmentamt': '12,000.00',
#       'repaymentfrequencycode': 'Not Available'}],
#     'accountmonthlypaymenthistoryheader': {'mh01': '2020\nAUG',
#      'mh02': '2020\nJUL',
#      'mh03': '2020\nJUN',
#      'mh04': '2020\nMAY',
#      'mh05': '2020\nAPR',
#      'mh06': '2020\nMAR',
#      'mh07': '2020\nFEB',
#      'mh08': '2020\nJAN',
#      'mh09': '2019\nDEC',
#      'mh10': '2019\nNOV',
#      'mh11': '2019\nOCT',
#      'mh12': '2019\nSEP',
#      'mh13': '2019\nAUG',
#      'mh14': '2019\nJUL',
#      'mh15': '2019\nJUN',
#      'mh16': '2019\nMAY',
#      'mh17': '2019\nAPR',
#      'mh18': '2019\nMAR',
#      'mh19': '2019\nFEB',
#      'mh20': '2019\nJAN',
#      'mh21': '2018\nDEC',
#      'mh22': '2018\nNOV',
#      'mh23': '2018\nOCT',
#      'mh24': '2018\nSEP',
#      'company': 'Company',
#      'tablename': 'Consumer24MonthlyPaymentHeader',
#      'displaytext': 'Consumer 24 Monthly Payment Header'}}}},
#  {'application_id': 9714953,
#   'data': {'consumerfullcredit': {'subjectlist': {'reference': '58793',
#      'consumerid': '58793',
#      'searchoutput': 'XXX'},
#     'accountrating': {'noofotheraccountsbad': '0',
#      'noofotheraccountsgood': '3',
#      'noofretailaccountsbad': '0',
#      'noofretailaccountsgood': '12',
#      'nooftelecomaccountsbad': '0',
#      'noofautoloanaccountsbad': '0',
#      'noofautoloanccountsgood': '0',
#      'noofhomeloanaccountsbad': '0',
#      'nooftelecomaccountsgood': '0',
#      'noofhomeloanaccountsgood': '0',
#      'noofjointloanaccountsbad': '0',
#      'noofstudyloanaccountsbad': '0',
#      'noofcreditcardaccountsbad': '0',
#      'noofjointloanaccountsgood': '0',
#      'noofstudyloanaccountsgood': '0',
#      'noofcreditcardaccountsgood': '0',
#      'noofpersonalloanaccountsbad': '0',
#      'noofpersonalloanaccountsgood': '2'},
#     'enquirydetails': {'productid': '45',
#      'matchingrate': '90',
#      'subscriberenquiryengineid': '5012883736',
#      'subscriberenquiryresultid': '6383644'},
#     'guarantorcount': {'accounts': '0', 'guarantorssecured': '0'},
#     'guarantordetails': {'guarantorgender': None,
#      'guarantorotherid': None,
#      'guarantoraddress1': None,
#      'guarantoraddress2': None,
#      'guarantoraddress3': None,
#      'guarantorpassport': None,
#      'guarantorfirstname': None,
#      'guarantorothername': None,
#      'guarantordateofbirth': '1900-01-01T00:00:00+01:00',
#      'guarantornationalidno': None,
#      'guarantorhometelephone': None,
#      'guarantorworktelephone': None,
#      'guarantordriverlicenceno': None,
#      'guarantormobiletelephone': None},
#     'telephonehistory': [{'homenoupdatedondate': '08/04/2016',
#       'hometelephonenumber': 'XXX',
#       'worktelephonenumber': '09075766710',
#       'mobilenoupdatedondate': '13/10/2016',
#       'mobiletelephonenumber': 'XXX'},
#      {'homenoupdatedondate': '18/01/2016',
#       'hometelephonenumber': 'XXX',
#       'mobilenoupdatedondate': '25/11/2014',
#       'mobiletelephonenumber': 'XXX'},
#      {'homenoupdatedondate': '25/11/2014',
#       'hometelephonenumber': 'XXX',
#       'mobiletelephonenumber': 'XXX'}],
#     'employmenthistory': [{'occupation': 'CIVIL SERVANT',
#       'updatedate': '21/11/2014',
#       'updateondate': '21/11/2014',
#       'employerdetail': None},
#      {'occupation': 'DOCTOR',
#       'employerdetail': 'MINISTRY OF WOMEN AFFAIRS AND SOCIAL DEVELOPMENT ABIA'},
#      {'occupation': 'DOCTOR',
#       'employerdetail': 'MINISTRY OF WOMEN AFFAIRS AND SOCIAL DEVELOPMENT'},
#      {'occupation': 'DOCTOR',
#       'employerdetail': 'MINISTRY OF WOMEN AFFAIRS AND SOCIAL DEVELOPMENT'},
#      {'occupation': 'DOCTOR'}],
#     'enquiryhistorytop': [{'daterequested': '31/07/2020 09:18:19',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '5974264'},
#      {'daterequested': '02/07/2020 07:01:37',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '5619239'},
#      {'daterequested': '24/06/2020 09:00:13',
#       'enquiryreason': 'A written consent from the client',
#       'subscribername': 'XGO Finance Limited - xgoapi',
#       'subscriberenquiryresultid': '5532915'},
#      {'daterequested': '13/06/2020 23:20:05',
#       'enquiryreason': 'A written consent from the client for sale',
#       'subscribername': 'XGO Finance Limited - xgoapi',
#       'subscriberenquiryresultid': '5434324'},
#      {'daterequested': '13/06/2020 22:21:34',
#       'enquiryreason': 'A written consent from the client for sale',
#       'subscribername': 'XGO Finance Limited - xgoapi',
#       'subscriberenquiryresultid': '5433899'},
#      {'daterequested': '09/06/2020 12:17:35',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '5370997'},
#      {'daterequested': '21/05/2020 23:02:30',
#       'enquiryreason': 'A written consent from the client for sale',
#       'subscribername': 'XGO Finance Limited - xgoapi',
#       'subscriberenquiryresultid': '5178049'},
#      {'daterequested': '29/02/2020 17:58:02',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '4533226'},
#      {'daterequested': '08/04/2019 12:52:49',
#       'enquiryreason': 'application of existing credit by a borrower',
#       'subscribername': 'NewEdge Finance Limited  - transsnet',
#       'subscriberenquiryresultid': '3135953'},
#      {'daterequested': '24/02/2018 07:52:51',
#       'enquiryreason': 'Application for credit by a borrower.',
#       'subscribername': 'First City Monument Bank Limited Lagos - Motunrayo Salako',
#       'companytelephoneno': None,
#       'subscriberenquiryresultid': '1657778'}],
#     'creditaccountsummary': {'rating': '2',
#      'amountarrear': '0.00',
#      'amountarrear1': '0.00',
#      'totalaccounts': '17',
#      'totalaccounts1': '0',
#      'lastjudgementdate': '-',
#      'lastjudgementdate1': '-',
#      'totalaccountarrear': '1',
#      'totalaccountarrear1': '0',
#      'totaljudgementamount': '0',
#      'totaloutstandingdebt': '294,770.00',
#      'totaljudgementamount1': '0',
#      'totaloutstandingdebt1': '0.00',
#      'totaldishonouredamount': '0.00',
#      'totalmonthlyinstalment': '132,176.00',
#      'totalnumberofjudgement': '0',
#      'totaldishonouredamount1': '0.00',
#      'totalmonthlyinstalment1': '0.00',
#      'totalnumberofjudgement1': '0',
#      'totalnumberofdishonoured': '0',
#      'totalnumberofdishonoured1': '0',
#      'totalaccountingodcondition': '0',
#      'totalaccountingodcondition1': '0'},
#     'deliquencyinformation': {'accountno': 'XXX',
#      'periodnum': '20170430',
#      'subscribername': 'First City Monument Bank Ltd Lagos',
#      'monthsinarrears': '2'},
#     'identificationhistory': [{'updatedate': '21/11/2014',
#       'updateondate': '21/11/2014',
#       'identificationtype': 'National ID Number',
#       'identificationnumber': 'XXX'},
#      {'updatedate': '17/01/2017',
#       'updateondate': '17/01/2017',
#       'identificationtype': 'National ID Number',
#       'identificationnumber': 'XXX'}],
#     'creditagreementsummary': [{'currency': 'NGN',
#       'accountno': '0494922010',
#       'closeddate': '30/12/2099',
#       'loanduration': '0',
#       'subaccountno': None,
#       'accountstatus': 'Open',
#       'amountoverdue': '0.00',
#       'subscribername': 'First City Monument Bank Ltd Lagos',
#       'lastupdateddate': '09/09/2019',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '30/08/2019',
#       'openingbalanceamt': '0.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Not Available',
#       'indicatordescription': 'Commercial Overdraft'},
#      {'currency': 'NGN',
#       'accountno': '0781209049492200',
#       'closeddate': '27/04/2023',
#       'loanduration': '1830',
#       'subaccountno': None,
#       'accountstatus': 'Open',
#       'amountoverdue': '0.00',
#       'subscribername': 'First City Monument Bank Ltd Lagos',
#       'lastupdateddate': '07/08/2020',
#       'instalmentamount': '11,988.13',
#       'currentbalanceamt': '275,770.06',
#       'dateaccountopened': '27/02/2018',
#       'openingbalanceamt': '129,000.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Monthly',
#       'indicatordescription': 'Personal secured loan'},
#      {'currency': 'NGN',
#       'accountno': '0784370494922001',
#       'closeddate': '01/06/2015',
#       'loanduration': '35',
#       'subaccountno': None,
#       'accountstatus': 'Paid Up',
#       'amountoverdue': '0.00',
#       'subscribername': 'First City Monument Bank Ltd Lagos',
#       'lastupdateddate': '08/08/2017',
#       'instalmentamount': '13,722.31',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '19/03/2012',
#       'openingbalanceamt': '217,000.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Monthly',
#       'indicatordescription': 'Installment account',
#       'currentbalancedebitind': 'C'},
#      {'currency': 'NGN',
#       'accountno': '0784560494922001',
#       'closeddate': '10/05/2017',
#       'loanduration': '181',
#       'subaccountno': None,
#       'accountstatus': 'closed',
#       'amountoverdue': '0.00',
#       'subscribername': 'First City Monument Bank Ltd Lagos',
#       'lastupdateddate': '15/09/2017',
#       'instalmentamount': '6,063.44',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '10/11/2016',
#       'openingbalanceamt': '112,600.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Monthly',
#       'indicatordescription': 'Personal cash loan',
#       'currentbalancedebitind': 'D'},
#      {'currency': 'NGN',
#       'accountno': '20200215183616525',
#       'closeddate': '28/02/2020',
#       'loanduration': '14',
#       'subaccountno': None,
#       'accountstatus': 'Writtenoff',
#       'amountoverdue': '0.00',
#       'subscribername': 'LCredit',
#       'lastupdateddate': '08/05/2020',
#       'instalmentamount': '0.00',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '15/02/2020',
#       'openingbalanceamt': '2,500.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Forthnightly',
#       'indicatordescription': None,
#       'currentbalancedebitind': None},
#      {'currency': 'NGN',
#       'accountno': '303544846479',
#       'closeddate': '11/06/2019',
#       'subaccountno': None,
#       'accountstatus': 'Closed',
#       'amountoverdue': '0.00',
#       'subscribername': 'One Finance & Investment Ltd',
#       'lastupdateddate': '27/12/2019',
#       'instalmentamount': '12,350.00',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '12/05/2019',
#       'openingbalanceamt': '9,500.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Not Available',
#       'indicatordescription': 'Personal fixed term loan'},
#      {'currency': 'NGN',
#       'accountno': '303695300279',
#       'closeddate': '15/07/2019',
#       'subaccountno': None,
#       'accountstatus': 'Closed',
#       'amountoverdue': '0.00',
#       'subscribername': 'One Finance & Investment Ltd',
#       'lastupdateddate': '27/12/2019',
#       'instalmentamount': '13,000.00',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '15/06/2019',
#       'openingbalanceamt': '10,000.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Not Available',
#       'indicatordescription': 'Personal fixed term loan'},
#      {'currency': 'NGN',
#       'accountno': '303870518370',
#       'closeddate': '15/08/2019',
#       'subaccountno': None,
#       'accountstatus': 'Closed',
#       'amountoverdue': '0.00',
#       'subscribername': 'One Finance & Investment Ltd',
#       'lastupdateddate': '27/12/2019',
#       'instalmentamount': '13,000.00',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '16/07/2019',
#       'openingbalanceamt': '10,000.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Not Available',
#       'indicatordescription': 'Personal fixed term loan'},
#      {'currency': 'NGN',
#       'accountno': '303983456537',
#       'closeddate': '30/09/2019',
#       'subaccountno': None,
#       'accountstatus': 'Closed',
#       'amountoverdue': '0.00',
#       'subscribername': 'One Finance & Investment Ltd',
#       'lastupdateddate': '27/12/2019',
#       'instalmentamount': '13,000.00',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '01/08/2019',
#       'openingbalanceamt': '20,000.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Not Available',
#       'indicatordescription': 'Personal fixed term loan'},
#      {'currency': 'NGN',
#       'accountno': '305331356561',
#       'closeddate': '22/03/2020',
#       'subaccountno': None,
#       'accountstatus': 'Closed',
#       'amountoverdue': '0.00',
#       'subscribername': 'One Finance & Investment Ltd',
#       'lastupdateddate': '17/08/2020',
#       'instalmentamount': '11,050.00',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '23/01/2020',
#       'openingbalanceamt': '17,000.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Not Available',
#       'indicatordescription': 'Personal fixed term loan'},
#      {'currency': 'NGN',
#       'accountno': '305656202288',
#       'closeddate': '30/03/2020',
#       'subaccountno': None,
#       'accountstatus': 'Closed',
#       'amountoverdue': '0.00',
#       'subscribername': 'One Finance & Investment Ltd',
#       'lastupdateddate': '17/08/2020',
#       'instalmentamount': '9,100.00',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '29/02/2020',
#       'openingbalanceamt': '7,000.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Not Available',
#       'indicatordescription': 'Personal fixed term loan'},
#      {'currency': 'NGN',
#       'accountno': '305881234141',
#       'closeddate': '27/04/2020',
#       'subaccountno': None,
#       'accountstatus': 'Open',
#       'amountoverdue': '0.00',
#       'subscribername': 'One Finance & Investment Ltd',
#       'lastupdateddate': '04/05/2020',
#       'instalmentamount': '3,002.50',
#       'currentbalanceamt': '2,500.00',
#       'dateaccountopened': '28/03/2020',
#       'openingbalanceamt': '2,500.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Not Available',
#       'indicatordescription': 'Personal fixed term loan'},
#      {'currency': 'NGN',
#       'accountno': '306106425538',
#       'closeddate': '06/06/2020',
#       'subaccountno': None,
#       'accountstatus': 'Closed',
#       'amountoverdue': '0.00',
#       'subscribername': 'One Finance & Investment Ltd',
#       'lastupdateddate': '17/08/2020',
#       'instalmentamount': '2,400.00',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '07/05/2020',
#       'openingbalanceamt': '2,000.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Not Available',
#       'indicatordescription': 'Personal fixed term loan'},
#      {'currency': 'NGN',
#       'accountno': '306228956927',
#       'closeddate': '30/06/2020',
#       'subaccountno': None,
#       'accountstatus': 'Closed',
#       'amountoverdue': '0.00',
#       'subscribername': 'One Finance & Investment Ltd',
#       'lastupdateddate': '17/08/2020',
#       'instalmentamount': '4,200.00',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '31/05/2020',
#       'openingbalanceamt': '3,500.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Not Available',
#       'indicatordescription': 'Personal fixed term loan'},
#      {'currency': 'NGN',
#       'accountno': '306407401093',
#       'closeddate': '01/08/2020',
#       'subaccountno': None,
#       'accountstatus': 'Closed',
#       'amountoverdue': '0.00',
#       'subscribername': 'One Finance & Investment Ltd',
#       'lastupdateddate': '17/08/2020',
#       'instalmentamount': '4,200.00',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '02/07/2020',
#       'openingbalanceamt': '3,500.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Not Available',
#       'indicatordescription': 'Personal fixed term loan'},
#      {'currency': 'NGN',
#       'accountno': '306592434031',
#       'closeddate': '30/10/2020',
#       'subaccountno': None,
#       'accountstatus': 'Open',
#       'amountoverdue': '0.00',
#       'subscribername': 'One Finance & Investment Ltd',
#       'lastupdateddate': '17/08/2020',
#       'instalmentamount': '7,232.50',
#       'currentbalanceamt': '16,500.00',
#       'dateaccountopened': '31/07/2020',
#       'openingbalanceamt': '16,500.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Not Available',
#       'indicatordescription': 'Personal fixed term loan'},
#      {'currency': 'NGN',
#       'accountno': '387058',
#       'closeddate': '22/01/2016',
#       'loanduration': '12',
#       'subaccountno': None,
#       'accountstatus': 'Closed',
#       'subscribername': 'Credit Direct Ltd Lagos',
#       'lastupdateddate': '24/10/2019',
#       'instalmentamount': '7,866.67',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '22/01/2015',
#       'openingbalanceamt': '59,000.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Monthly'}],
#     'personaldetailssummary': {'gender': 'Female',
#      'header': 'PERSONAL DETAILS SUMMARY: XXX',
#      'surname': 'XXX',
#      'birthdate': '30/11/1985',
#      'firstname': 'XXX',
#      'otheridno': None,
#      'cellularno': '07062688658',
#      'consumerid': '58793',
#      'dependants': '0',
#      'othernames': 'XXX',
#      'pencomidno': None,
#      'nationality': 'Nigeria',
#      'emailaddress': None,
#      'nationalidno': 'XXX',
#      'employerdetail': None,
#      'postaladdress1': 'XXX',
#      'postaladdress2': 'UMUAHIA',
#      'postaladdress3': None,
#      'postaladdress4': {'xml:space': 'preserve', '__content__': ' '},
#      'hometelephoneno': 'XXX',
#      'worktelephoneno': 'XXX',
#      'propertyownedtype': None,
#      'bankverificationno': '221XXX82472688',
#      'residentialaddress1': 'XXX',
#      'residentialaddress2': 'UMUAHIA',
#      'residentialaddress3': None,
#      'residentialaddress4': {'xml:space': 'preserve', '__content__': ' '}},
#     'accountmonthlypaymenthistory': [{'m01': '#',
#       'm02': '#',
#       'm03': '#',
#       'm04': '#',
#       'm05': '#',
#       'm06': '#',
#       'm07': '#',
#       'm08': '#',
#       'm09': '#',
#       'm10': '#',
#       'm11': '#',
#       'm12': '#',
#       'm13': '0',
#       'm14': '0',
#       'm15': '#',
#       'm16': '#',
#       'm17': '#',
#       'm18': '#',
#       'm19': '#',
#       'm20': '#',
#       'm21': '#',
#       'm22': '0',
#       'm23': '#',
#       'm24': '#',
#       'header': 'Details of Credit Agreement with "Credit Direct Ltd Lagos" for Account Number: 387058',
#       'currency': 'NGN',
#       'accountno': '387058',
#       'tablename': 'Consumer24MonthlyPayment',
#       'closeddate': '22/01/2016',
#       'accountnote': None,
#       'displaytext': 'Consumer 24 Monthly Payment',
#       'loanduration': '12 Day(s)',
#       'subaccountno': None,
#       'accountstatus': 'Closed',
#       'subscribername': 'Credit Direct Ltd Lagos',
#       'lastpaymentdate': '18/04/2016',
#       'lastupdateddate': '24/10/2019',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '22/01/2015',
#       'openingbalanceamt': '59,000.00',
#       'performancestatus': 'Performing',
#       'subscribertypeind': 'F',
#       'monthlyinstalmentamt': '7,866.67',
#       'repaymentfrequencycode': 'Monthly'},
#      {'m01': '#',
#       'm02': '#',
#       'm03': '#',
#       'm04': '#',
#       'm05': '#',
#       'm06': '#',
#       'm07': '#',
#       'm08': '#',
#       'm09': '#',
#       'm10': '#',
#       'm11': '#',
#       'm12': '#',
#       'm13': '#',
#       'm14': '0',
#       'm15': '#',
#       'm16': '#',
#       'm17': '#',
#       'm18': '#',
#       'm19': '#',
#       'm20': '#',
#       'm21': '#',
#       'm22': '#',
#       'm23': '#',
#       'm24': '#',
#       'header': 'Details of Credit Agreement with "First City Monument Bank Ltd Lagos" for Account Number: 0494922010',
#       'currency': 'NGN',
#       'accountno': '0494922010',
#       'tablename': 'Consumer24MonthlyPayment',
#       'closeddate': '30/12/2099',
#       'accountnote': None,
#       'displaytext': 'Consumer 24 Monthly Payment',
#       'loanduration': 'Not Available',
#       'subaccountno': None,
#       'accountstatus': 'Open',
#       'amountoverdue': '0.00',
#       'subscribername': 'First City Monument Bank Ltd Lagos',
#       'lastpaymentdate': '22/08/2019',
#       'lastupdateddate': '09/09/2019',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '30/08/2019',
#       'openingbalanceamt': '0.00',
#       'performancestatus': 'Performing',
#       'subscribertypeind': 'C',
#       'indicatordescription': 'Commercial Overdraft',
#       'repaymentfrequencycode': 'Not Available'},
#      {'m01': '#',
#       'm02': '#',
#       'm03': '0',
#       'm04': '0',
#       'm05': '5',
#       'm06': '0',
#       'm07': '0',
#       'm08': '10',
#       'm09': '10',
#       'm10': '5',
#       'm11': '0',
#       'm12': '5',
#       'm13': '0',
#       'm14': '0',
#       'm15': '0',
#       'm16': '4',
#       'm17': '8',
#       'm18': '9',
#       'm19': '0',
#       'm20': '6',
#       'm21': '40',
#       'm22': '6',
#       'm23': '8',
#       'm24': '9',
#       'header': 'Details of Credit Agreement with "First City Monument Bank Ltd Lagos" for Account Number: 0781209049492200',
#       'currency': 'NGN',
#       'accountno': '0781209049492200',
#       'tablename': 'Consumer24MonthlyPayment',
#       'closeddate': '27/04/2023',
#       'accountnote': None,
#       'displaytext': 'Consumer 24 Monthly Payment',
#       'loanduration': '1830 Day(s)',
#       'subaccountno': None,
#       'accountstatus': 'Open',
#       'amountoverdue': '0.00',
#       'subscribername': 'First City Monument Bank Ltd Lagos',
#       'lastpaymentdate': '29/07/2020',
#       'lastupdateddate': '07/08/2020',
#       'currentbalanceamt': '275,770.06',
#       'dateaccountopened': '27/02/2018',
#       'openingbalanceamt': '129,000.00',
#       'performancestatus': 'Performing',
#       'subscribertypeind': 'C',
#       'indicatordescription': 'Personal secured loan',
#       'monthlyinstalmentamt': '11,988.13',
#       'repaymentfrequencycode': 'Monthly'},
#      {'m01': '#',
#       'm02': '#',
#       'm03': '#',
#       'm04': '#',
#       'm05': '#',
#       'm06': '#',
#       'm07': '#',
#       'm08': '#',
#       'm09': '#',
#       'm10': '#',
#       'm11': '#',
#       'm12': '#',
#       'm13': '#',
#       'm14': '#',
#       'm15': '#',
#       'm16': '#',
#       'm17': '#',
#       'm18': '#',
#       'm19': '#',
#       'm20': '#',
#       'm21': '#',
#       'm22': '#',
#       'm23': '#',
#       'm24': '#',
#       'header': 'Details of Credit Agreement with "First City Monument Bank Ltd Lagos" for Account Number: 0784370494922001',
#       'currency': 'NGN',
#       'accountno': '0784370494922001',
#       'tablename': 'Consumer24MonthlyPayment',
#       'closeddate': '01/06/2015',
#       'accountnote': None,
#       'displaytext': 'Consumer 24 Monthly Payment',
#       'loanduration': '35 Day(s)',
#       'subaccountno': None,
#       'accountstatus': 'Paid Up',
#       'amountoverdue': '0.00',
#       'subscribername': 'First City Monument Bank Ltd Lagos',
#       'lastpaymentdate': '09/09/2014',
#       'lastupdateddate': '08/08/2017',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '19/03/2012',
#       'openingbalanceamt': '217,000.00',
#       'performancestatus': 'Performing',
#       'subscribertypeind': 'C',
#       'indicatordescription': 'Installment account',
#       'monthlyinstalmentamt': '13,722.31',
#       'currentbalancedebitind': 'C',
#       'repaymentfrequencycode': 'Monthly'},
#      {'m01': '#',
#       'm02': '#',
#       'm03': '#',
#       'm04': '#',
#       'm05': '#',
#       'm06': '#',
#       'm07': '#',
#       'm08': '#',
#       'm09': '#',
#       'm10': '#',
#       'm11': '#',
#       'm12': '#',
#       'm13': '#',
#       'm14': '#',
#       'm15': '#',
#       'm16': '#',
#       'm17': '#',
#       'm18': '#',
#       'm19': '#',
#       'm20': '#',
#       'm21': '#',
#       'm22': '#',
#       'm23': '#',
#       'm24': '#',
#       'header': 'Details of Credit Agreement with "First City Monument Bank Ltd Lagos" for Account Number: 0784560494922001',
#       'currency': 'NGN',
#       'accountno': '0784560494922001',
#       'tablename': 'Consumer24MonthlyPayment',
#       'closeddate': '10/05/2017',
#       'accountnote': None,
#       'displaytext': 'Consumer 24 Monthly Payment',
#       'loanduration': '181 Day(s)',
#       'subaccountno': None,
#       'accountstatus': 'closed',
#       'amountoverdue': '0.00',
#       'subscribername': 'First City Monument Bank Ltd Lagos',
#       'lastpaymentdate': '03/04/2017',
#       'lastupdateddate': '15/09/2017',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '10/11/2016',
#       'openingbalanceamt': '112,600.00',
#       'performancestatus': 'Performing',
#       'subscribertypeind': 'C',
#       'indicatordescription': 'Personal cash loan',
#       'monthlyinstalmentamt': '6,063.44',
#       'currentbalancedebitind': 'D',
#       'repaymentfrequencycode': 'Monthly'},
#      {'m01': '#',
#       'm02': '#',
#       'm03': '#',
#       'm04': '#',
#       'm05': '#',
#       'm06': '#',
#       'm07': '#',
#       'm08': '0',
#       'm09': '#',
#       'm10': '#',
#       'm11': '#',
#       'm12': '#',
#       'm13': '#',
#       'm14': '#',
#       'm15': '#',
#       'm16': '#',
#       'm17': '#',
#       'm18': '#',
#       'm19': '#',
#       'm20': '#',
#       'm21': '#',
#       'm22': '#',
#       'm23': '#',
#       'm24': '#',
#       'header': 'Details of Credit Agreement with "LCredit" for Account Number: 20200215183616525',
#       'currency': 'NGN',
#       'accountno': '20200215183616525',
#       'tablename': 'Consumer24MonthlyPayment',
#       'closeddate': '28/02/2020',
#       'accountnote': None,
#       'displaytext': 'Consumer 24 Monthly Payment',
#       'loanduration': '14 Day(s)',
#       'subaccountno': None,
#       'accountstatus': 'Writtenoff',
#       'amountoverdue': '0.00',
#       'subscribername': 'LCredit',
#       'lastpaymentdate': '29/02/2020',
#       'lastupdateddate': '08/05/2020',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '15/02/2020',
#       'openingbalanceamt': '2,500.00',
#       'performancestatus': 'Performing',
#       'subscribertypeind': 'E',
#       'indicatordescription': None,
#       'monthlyinstalmentamt': '0.00',
#       'currentbalancedebitind': None,
#       'repaymentfrequencycode': 'Forthnightly'},
#      {'m01': '#',
#       'm02': '#',
#       'm03': '#',
#       'm04': '#',
#       'm05': '#',
#       'm06': '#',
#       'm07': '#',
#       'm08': '#',
#       'm09': '#',
#       'm10': '#',
#       'm11': '0',
#       'm12': '#',
#       'm13': '#',
#       'm14': '0',
#       'm15': '#',
#       'm16': '#',
#       'm17': '#',
#       'm18': '#',
#       'm19': '#',
#       'm20': '#',
#       'm21': '#',
#       'm22': '#',
#       'm23': '#',
#       'm24': '#',
#       'header': 'Details of Credit Agreement with "One Finance & Investment Ltd" for Account Number: 303544846479',
#       'currency': 'NGN',
#       'accountno': '303544846479',
#       'tablename': 'Consumer24MonthlyPayment',
#       'closeddate': '11/06/2019',
#       'accountnote': None,
#       'displaytext': 'Consumer 24 Monthly Payment',
#       'loanduration': 'Not Available',
# ...
#       'm13': '#',
#       'm14': '#',
#       'm15': '#',
#       'm16': '#',
#       'm17': '#',
#       'm18': '#',
#       'm19': '#',
#       'm20': '#',
#       'm21': '#',
#       'm22': '#',
#       'm23': '#',
#       'm24': '#',
#       'header': 'Details of Credit Agreement with "One Finance & Investment Ltd" for Account Number: 306407401093',
#       'currency': 'NGN',
#       'accountno': '306407401093',
#       'tablename': 'Consumer24MonthlyPayment',
#       'closeddate': '01/08/2020',
#       'accountnote': None,
#       'displaytext': 'Consumer 24 Monthly Payment',
#       'loanduration': 'Not Available',
#       'subaccountno': None,
#       'accountstatus': 'Closed',
#       'amountoverdue': '0.00',
#       'subscribername': 'One Finance & Investment Ltd',
#       'lastupdateddate': '17/08/2020',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '02/07/2020',
#       'openingbalanceamt': '3,500.00',
#       'performancestatus': 'Performing',
#       'subscribertypeind': 'F',
#       'indicatordescription': 'Personal fixed term loan',
#       'monthlyinstalmentamt': '4,200.00',
#       'repaymentfrequencycode': 'Not Available'},
#      {'m01': '#',
#       'm02': '#',
#       'm03': '0',
#       'm04': '#',
#       'm05': '#',
#       'm06': '#',
#       'm07': '#',
#       'm08': '#',
#       'm09': '#',
#       'm10': '#',
#       'm11': '#',
#       'm12': '#',
#       'm13': '#',
#       'm14': '#',
#       'm15': '#',
#       'm16': '#',
#       'm17': '#',
#       'm18': '#',
#       'm19': '#',
#       'm20': '#',
#       'm21': '#',
#       'm22': '#',
#       'm23': '#',
#       'm24': '#',
#       'header': 'Details of Credit Agreement with "One Finance & Investment Ltd" for Account Number: 306592434031',
#       'currency': 'NGN',
#       'accountno': '306592434031',
#       'tablename': 'Consumer24MonthlyPayment',
#       'closeddate': '30/10/2020',
#       'accountnote': None,
#       'displaytext': 'Consumer 24 Monthly Payment',
#       'loanduration': 'Not Available',
#       'subaccountno': None,
#       'accountstatus': 'Open',
#       'amountoverdue': '0.00',
#       'subscribername': 'One Finance & Investment Ltd',
#       'lastupdateddate': '17/08/2020',
#       'currentbalanceamt': '16,500.00',
#       'dateaccountopened': '31/07/2020',
#       'openingbalanceamt': '16,500.00',
#       'performancestatus': 'Performing',
#       'subscribertypeind': 'F',
#       'indicatordescription': 'Personal fixed term loan',
#       'monthlyinstalmentamt': '7,232.50',
#       'repaymentfrequencycode': 'Not Available'}],
#     'accountmonthlypaymenthistoryheader': {'mh01': '2020\nSEP',
#      'mh02': '2020\nAUG',
#      'mh03': '2020\nJUL',
#      'mh04': '2020\nJUN',
#      'mh05': '2020\nMAY',
#      'mh06': '2020\nAPR',
#      'mh07': '2020\nMAR',
#      'mh08': '2020\nFEB',
#      'mh09': '2020\nJAN',
#      'mh10': '2019\nDEC',
#      'mh11': '2019\nNOV',
#      'mh12': '2019\nOCT',
#      'mh13': '2019\nSEP',
#      'mh14': '2019\nAUG',
#      'mh15': '2019\nJUL',
#      'mh16': '2019\nJUN',
#      'mh17': '2019\nMAY',
#      'mh18': '2019\nAPR',
#      'mh19': '2019\nMAR',
#      'mh20': '2019\nFEB',
#      'mh21': '2019\nJAN',
#      'mh22': '2018\nDEC',
#      'mh23': '2018\nNOV',
#      'mh24': '2018\nOCT',
#      'company': 'Company',
#      'tablename': 'Consumer24MonthlyPaymentHeader',
#      'displaytext': 'Consumer 24 Monthly Payment Header'}}}},
#  {'application_id': 9714978,
#   'data': {'consumerfullcredit': {'subjectlist': {'reference': '17688366',
#      'consumerid': '17688366',
#      'searchoutput': 'XXX'},
#     'accountrating': {'noofotheraccountsbad': '0',
#      'noofotheraccountsgood': '1',
#      'noofretailaccountsbad': '1',
#      'noofretailaccountsgood': '1',
#      'nooftelecomaccountsbad': '0',
#      'noofautoloanaccountsbad': '0',
#      'noofautoloanccountsgood': '0',
#      'noofhomeloanaccountsbad': '0',
#      'nooftelecomaccountsgood': '0',
#      'noofhomeloanaccountsgood': '0',
#      'noofjointloanaccountsbad': '0',
#      'noofstudyloanaccountsbad': '0',
#      'noofcreditcardaccountsbad': '0',
#      'noofjointloanaccountsgood': '0',
#      'noofstudyloanaccountsgood': '0',
#      'noofcreditcardaccountsgood': '0',
#      'noofpersonalloanaccountsbad': '0',
#      'noofpersonalloanaccountsgood': '0'},
#     'enquirydetails': {'productid': '45',
#      'matchingrate': '90',
#      'subscriberenquiryengineid': '5012883827',
#      'subscriberenquiryresultid': '6383655'},
#     'guarantorcount': {'accounts': '0', 'guarantorssecured': '0'},
#     'guarantordetails': {'guarantorgender': None,
#      'guarantorotherid': None,
#      'guarantoraddress1': None,
#      'guarantoraddress2': None,
#      'guarantoraddress3': None,
#      'guarantorpassport': None,
#      'guarantorfirstname': None,
#      'guarantorothername': None,
#      'guarantordateofbirth': '1900-01-01T00:00:00+01:00',
#      'guarantornationalidno': None,
#      'guarantorhometelephone': None,
#      'guarantorworktelephone': None,
#      'guarantordriverlicenceno': None,
#      'guarantormobiletelephone': None},
#     'telephonehistory': [{'mobiletelephonenumber': 'XXX'},
#      {'mobiletelephonenumber': 'XXX'},
#      {'mobiletelephonenumber': 'XXX'}],
#     'employmenthistory': [{'occupation': 'STUDENT'},
#      {'occupation': 'STUDENT'},
#      {'occupation': 'STUDENT'},
#      {'occupation': 'STUDENT'},
#      {'occupation': 'STUDENT'}],
#     'enquiryhistorytop': [{'daterequested': '31/07/2020 08:47:15',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '5973926'},
#      {'daterequested': '21/07/2020 23:48:04',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '5856359'},
#      {'daterequested': '13/06/2020 22:29:07',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '5433973'},
#      {'daterequested': '08/06/2020 22:05:09',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '5365360'},
#      {'daterequested': '16/05/2020 02:13:03',
#       'enquiryreason': 'A written consent from the client for sale',
#       'subscribername': 'XGO Finance Limited - xgoapi',
#       'subscriberenquiryresultid': '5113016'},
#      {'daterequested': '13/03/2020 09:12:27',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '4719695'},
#      {'daterequested': '13/03/2020 09:07:04',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '4719631'},
#      {'daterequested': '06/03/2020 07:31:10',
#       'enquiryreason': 'A written consent from the client',
#       'subscribername': 'XGO Finance Limited - xgoapi',
#       'subscriberenquiryresultid': '4617903'},
#      {'daterequested': '13/02/2020 13:19:00',
#       'enquiryreason': 'Credit scoring of the client by credit bureau',
#       'subscribername': 'CDL - Credit Direct API',
#       'subscriberenquiryresultid': '4405031'},
#      {'daterequested': '26/10/2019 21:35:04',
#       'enquiryreason': 'application of existing credit by a borrower',
#       'subscribername': 'NewEdge Finance Limited  - transsnet',
#       'subscriberenquiryresultid': '3925276'}],
#     'creditaccountsummary': {'rating': '109',
#      'amountarrear': '12,000.00',
#      'amountarrear1': '0.00',
#      'totalaccounts': '3',
#      'totalaccounts1': '0',
#      'lastjudgementdate': '-',
#      'lastjudgementdate1': '-',
#      'totalaccountarrear': '1',
#      'totalaccountarrear1': '0',
#      'totaljudgementamount': '0',
#      'totaloutstandingdebt': '110,919.00',
#      'totaljudgementamount1': '0',
#      'totaloutstandingdebt1': '0.00',
#      'totaldishonouredamount': '0.00',
#      'totalmonthlyinstalment': '7,000.00',
#      'totalnumberofjudgement': '0',
#      'totaldishonouredamount1': '0.00',
#      'totalmonthlyinstalment1': '0.00',
#      'totalnumberofjudgement1': '0',
#      'totalnumberofdishonoured': '0',
#      'totalnumberofdishonoured1': '0',
#      'totalaccountingodcondition': '0',
#      'totalaccountingodcondition1': '0'},
#     'deliquencyinformation': {'accountno': '4181042465',
#      'periodnum': '20200630',
#      'subscribername': 'Branch International Financial Services Limited',
#      'monthsinarrears': '109'},
#     'creditagreementsummary': [{'currency': 'NGN',
#       'accountno': '023802281040010059000',
#       'closeddate': '29/07/2020',
#       'loanduration': '1',
#       'subaccountno': None,
#       'accountstatus': 'Open',
#       'amountoverdue': '0.00',
#       'subscribername': 'Guaranty Trust Bank Plc',
#       'lastupdateddate': '07/08/2020',
#       'instalmentamount': '7,000.00',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '31/07/2020',
#       'openingbalanceamt': '0.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Monthly',
#       'indicatordescription': 'Personal Overdraft'},
#      {'currency': 'NGN',
#       'accountno': '023802281040011118000',
#       'closeddate': '31/08/2020',
#       'loanduration': '374',
#       'subaccountno': None,
#       'accountstatus': 'Open',
#       'amountoverdue': '0.00',
#       'subscribername': 'Guaranty Trust Bank Plc',
#       'lastupdateddate': '07/08/2020',
#       'instalmentamount': '0.00',
#       'currentbalanceamt': '98,919.00',
#       'dateaccountopened': '23/08/2019',
#       'openingbalanceamt': '1,080,936.00',
#       'performancestatus': 'Performing',
#       'repaymentfrequency': 'Monthly',
#       'indicatordescription': 'Personal fixed term loan'},
#      {'currency': 'NGN',
#       'accountno': '4181042465',
#       'closeddate': '14/03/2020',
#       'loanduration': '0',
#       'subaccountno': None,
#       'accountstatus': 'Open',
#       'amountoverdue': '12,000.00',
#       'subscribername': 'Branch International Financial Services Limited',
#       'lastupdateddate': '02/08/2020',
#       'instalmentamount': '0.00',
#       'currentbalanceamt': '12,000.00',
#       'dateaccountopened': '15/02/2020',
#       'openingbalanceamt': '10,000.00',
#       'performancestatus': 'Lost',
#       'repaymentfrequency': 'Monthly',
#       'indicatordescription': 'Personal fixed term loan',
#       'currentbalancedebitind': None}],
#     'personaldetailssummary': {'gender': 'Female',
#      'header': 'PERSONAL DETAILS SUMMARY: XXX',
#      'surname': 'XXX',
#      'birthdate': '14/07/1983',
#      'firstname': 'XXX',
#      'otheridno': None,
#      'cellularno': 'XXX',
#      'consumerid': '17688366',
#      'dependants': '0',
#      'othernames': 'XXX',
#      'passportno': 'XXX',
#      'pencomidno': None,
#      'nationality': 'Nigeria',
#      'emailaddress': None,
#      'nationalidno': None,
#      'employerdetail': None,
#      'propertyownedtype': None,
#      'bankverificationno': 'XXX',
#      'residentialaddress1': 'Nigeria',
#      'residentialaddress2': 'Nigeria',
#      'residentialaddress3': None,
#      'residentialaddress4': ' Nigeria'},
#     'accountmonthlypaymenthistory': [{'m01': '#',
#       'm02': '#',
#       'm03': '#',
#       'm04': '109',
#       'm05': '#',
#       'm06': '#',
#       'm07': '#',
#       'm08': '#',
#       'm09': '#',
#       'm10': '#',
#       'm11': '#',
#       'm12': '#',
#       'm13': '#',
#       'm14': '#',
#       'm15': '#',
#       'm16': '#',
#       'm17': '#',
#       'm18': '#',
#       'm19': '#',
#       'm20': '#',
#       'm21': '#',
#       'm22': '#',
#       'm23': '#',
#       'm24': '#',
#       'header': 'Details of Credit Agreement with "Branch International Financial Services Limited" for Account Number: 4181042465',
#       'currency': 'NGN',
#       'accountno': '4181042465',
#       'tablename': 'Consumer24MonthlyPayment',
#       'closeddate': '14/03/2020',
#       'accountnote': None,
#       'displaytext': 'Consumer 24 Monthly Payment',
#       'loanduration': 'Not Available',
#       'subaccountno': None,
#       'accountstatus': 'Open',
#       'amountoverdue': '12,000.00',
#       'subscribername': 'Branch International Financial Services Limited',
#       'lastpaymentdate': '14/03/2020',
#       'lastupdateddate': '02/08/2020',
#       'currentbalanceamt': '12,000.00',
#       'dateaccountopened': '15/02/2020',
#       'openingbalanceamt': '10,000.00',
#       'performancestatus': 'Lost',
#       'subscribertypeind': 'M',
#       'indicatordescription': 'Personal fixed term loan',
#       'monthlyinstalmentamt': '0.00',
#       'currentbalancedebitind': None,
#       'repaymentfrequencycode': 'Monthly'},
#      {'m01': '#',
#       'm02': '#',
#       'm03': '0',
#       'm04': '0',
#       'm05': '0',
#       'm06': '0',
#       'm07': '1',
#       'm08': '0',
#       'm09': '2',
#       'm10': '0',
#       'm11': '0',
#       'm12': '0',
#       'm13': '0',
#       'm14': '0',
#       'm15': '#',
#       'm16': '#',
#       'm17': '#',
#       'm18': '#',
#       'm19': '#',
#       'm20': '#',
#       'm21': '#',
#       'm22': '#',
#       'm23': '#',
#       'm24': '#',
#       'header': 'Details of Credit Agreement with "Guaranty Trust Bank Plc" for Account Number: 023802281040010059000',
#       'currency': 'NGN',
#       'accountno': '023802281040010059000',
#       'tablename': 'Consumer24MonthlyPayment',
#       'closeddate': '29/07/2020',
#       'accountnote': None,
#       'displaytext': 'Consumer 24 Monthly Payment',
#       'loanduration': '1 Day(s)',
#       'subaccountno': None,
#       'accountstatus': 'Open',
#       'amountoverdue': '0.00',
#       'subscribername': 'Guaranty Trust Bank Plc',
#       'lastpaymentdate': '29/07/2020',
#       'lastupdateddate': '07/08/2020',
#       'currentbalanceamt': '0.00',
#       'dateaccountopened': '31/07/2020',
#       'openingbalanceamt': '0.00',
#       'performancestatus': 'Performing',
#       'subscribertypeind': 'C',
#       'indicatordescription': 'Personal Overdraft',
#       'monthlyinstalmentamt': '7,000.00',
#       'repaymentfrequencycode': 'Monthly'},
#      {'m01': '#',
#       'm02': '#',
#       'm03': '0',
#       'm04': '0',
#       'm05': '0',
#       'm06': '0',
#       'm07': '0',
#       'm08': '0',
#       'm09': '0',
#       'm10': '0',
#       'm11': '0',
#       'm12': '0',
#       'm13': '0',
#       'm14': '0',
#       'm15': '#',
#       'm16': '#',
#       'm17': '#',
#       'm18': '#',
#       'm19': '#',
#       'm20': '#',
#       'm21': '#',
#       'm22': '#',
#       'm23': '#',
#       'm24': '#',
#       'header': 'Details of Credit Agreement with "Guaranty Trust Bank Plc" for Account Number: 023802281040011118000',
#       'currency': 'NGN',
#       'accountno': '023802281040011118000',
#       'tablename': 'Consumer24MonthlyPayment',
#       'closeddate': '31/08/2020',
#       'accountnote': None,
#       'displaytext': 'Consumer 24 Monthly Payment',
#       'loanduration': '374 Day(s)',
#       'subaccountno': None,
#       'accountstatus': 'Open',
#       'amountoverdue': '0.00',
#       'subscribername': 'Guaranty Trust Bank Plc',
#       'lastpaymentdate': '23/08/2019',
#       'lastupdateddate': '07/08/2020',
#       'currentbalanceamt': '98,919.00',
#       'dateaccountopened': '23/08/2019',
#       'openingbalanceamt': '1,080,936.00',
#       'performancestatus': 'Performing',
#       'subscribertypeind': 'C',
#       'indicatordescription': 'Personal fixed term loan',
#       'monthlyinstalmentamt': '0.00',
#       'repaymentfrequencycode': 'Monthly'}],
#     'accountmonthlypaymenthistoryheader': {'mh01': '2020\nSEP',
#      'mh02': '2020\nAUG',
#      'mh03': '2020\nJUL',
#      'mh04': '2020\nJUN',
#      'mh05': '2020\nMAY',
#      'mh06': '2020\nAPR',
#      'mh07': '2020\nMAR',
#      'mh08': '2020\nFEB',
#      'mh09': '2020\nJAN',
#      'mh10': '2019\nDEC',
#      'mh11': '2019\nNOV',
#      'mh12': '2019\nOCT',
#      'mh13': '2019\nSEP',
#      'mh14': '2019\nAUG',
#      'mh15': '2019\nJUL',
#      'mh16': '2019\nJUN',
#      'mh17': '2019\nMAY',
#      'mh18': '2019\nAPR',
#      'mh19': '2019\nMAR',
#      'mh20': '2019\nFEB',
#      'mh21': '2019\nJAN',
#      'mh22': '2018\nDEC',
#      'mh23': '2018\nNOV',
#      'mh24': '2018\nOCT',
#      'company': 'Company',
#      'tablename': 'Consumer24MonthlyPaymentHeader',
#      'displaytext': 'Consumer 24 Monthly Payment Header'}}}}]

# %% [markdown]
# The decision making data for each applicant are stored in the key 'consumerfullcredit' within the key 'data' in the JSON data

# %% [markdown]
# The categories of decision making data are computed as follows:

# %%
set(credit_reports[0]['data']['consumerfullcredit'])
# Out:
# {'accountmonthlypaymenthistory',
#  'accountmonthlypaymenthistoryheader',
#  'accountrating',
#  'creditaccountsummary',
#  'creditagreementsummary',
#  'deliquencyinformation',
#  'employmenthistory',
#  'enquirydetails',
#  'enquiryhistorytop',
#  'guarantorcount',
#  'guarantordetails',
#  'personaldetailssummary',
#  'subjectlist',
#  'telephonehistory'}

# %% [markdown]
# It's important to observe the info in each categories

# %% [markdown]
# 1. Personal details Summary

# %%
credit_reports[0]['data']['consumerfullcredit']['personaldetailssummary']
# Out:
# {'gender': 'Male',
#  'header': 'PERSONAL DETAILS SUMMARY: XXX',
#  'surname': 'XXX',
#  'birthdate': '06/05/1991',
#  'firstname': 'XXX',
#  'otheridno': None,
#  'cellularno': 'XXX',
#  'consumerid': '128566',
#  'dependants': '0',
#  'othernames': 'XXX',
#  'pencomidno': None,
#  'nationality': 'Nigeria',
#  'emailaddress': None,
#  'nationalidno': None,
#  'employerdetail': 'ALL MILITARY STAFFS',
#  'postaladdress1': 'XXX ',
#  'postaladdress2': 'KADUNA STATE NIGERIA',
#  'postaladdress3': None,
#  'postaladdress4': {'xml:space': 'preserve', '__content__': ' '},
#  'hometelephoneno': 'XXX',
#  'propertyownedtype': None,
#  'bankverificationno': 'XXX',
#  'residentialaddress1': 'XXX ',
#  'residentialaddress2': 'KADUNA STATE  NIGERIA',
#  'residentialaddress3': None,
#  'residentialaddress4': {'xml:space': 'preserve', '__content__': ' '}}

# %% [markdown]
# <br>

# %% [markdown]
# 2.Employment History

# %%
credit_reports[0]['data']['consumerfullcredit']['employmenthistory']
# Out:
# [{'occupation': 'PUBLIC SERVANTS',
#   'updatedate': '16/09/2016',
#   'updateondate': '16/09/2016',
#   'employerdetail': 'ALL MILITARY STAFFS'},
#  {'occupation': 'PUBLIC SERVANTS'},
#  {'occupation': 'PUBLIC SERVANTS'},
#  {'occupation': 'Army Police Defence', 'employerdetail': 'Nigerian navy'},
#  {'occupation': 'PUBLIC SERVANTS'}]

# %% [markdown]
# <br>

# %% [markdown]
# 3. Telephone history

# %%
credit_reports[0]['data']['consumerfullcredit']['telephonehistory']
# Out:
# [{'homenoupdatedondate': '08/04/2016',
#   'hometelephonenumber': 'XXX',
#   'mobiletelephonenumber': 'XXX'},
#  {'homenoupdatedondate': '18/01/2016',
#   'hometelephonenumber': 'XXX',
#   'mobiletelephonenumber': 'XXX'},
#  {'homenoupdatedondate': '27/08/2015',
#   'hometelephonenumber': 'XXX',
#   'mobiletelephonenumber': 'XXX'}]

# %% [markdown]
# <br>

# %% [markdown]
# 4. Gaurantor Count

# %%
credit_reports[0]['data']['consumerfullcredit']['guarantorcount']
# Out:
# {'accounts': '0', 'guarantorssecured': '0'}

# %% [markdown]
# <br>

# %% [markdown]
# 5. Gaurantor Details

# %%
credit_reports[0]['data']['consumerfullcredit']['guarantordetails']
# Out:
# {'guarantorgender': None,
#  'guarantorotherid': None,
#  'guarantoraddress1': None,
#  'guarantoraddress2': None,
#  'guarantoraddress3': None,
#  'guarantorpassport': None,
#  'guarantorfirstname': None,
#  'guarantorothername': None,
#  'guarantordateofbirth': '1900-01-01T00:00:00+01:00',
#  'guarantornationalidno': None,
#  'guarantorhometelephone': None,
#  'guarantorworktelephone': None,
#  'guarantordriverlicenceno': None,
#  'guarantormobiletelephone': None}

# %% [markdown]
# <br>

# %% [markdown]
# 6. delinquency information

# %%
credit_reports[0]['data']['consumerfullcredit']['deliquencyinformation']
# Out:
# {'accountno': '2150224012',
#  'periodnum': '20140930',
#  'subscribername': 'First City Monument Bank Ltd Lagos',
#  'monthsinarrears': '13'}

# %% [markdown]
# <br>

# %% [markdown]
# 7.Account Rating

# %%
credit_reports[0]['data']['consumerfullcredit']['accountrating']
# Out:
# {'noofotheraccountsbad': '0',
#  'noofotheraccountsgood': '3',
#  'noofretailaccountsbad': '0',
#  'noofretailaccountsgood': '2',
#  'nooftelecomaccountsbad': '0',
#  'noofautoloanaccountsbad': '0',
#  'noofautoloanccountsgood': '0',
#  'noofhomeloanaccountsbad': '0',
#  'nooftelecomaccountsgood': '0',
#  'noofhomeloanaccountsgood': '0',
#  'noofjointloanaccountsbad': '0',
#  'noofstudyloanaccountsbad': '0',
#  'noofcreditcardaccountsbad': '0',
#  'noofjointloanaccountsgood': '0',
#  'noofstudyloanaccountsgood': '0',
#  'noofcreditcardaccountsgood': '1',
#  'noofpersonalloanaccountsbad': '0',
#  'noofpersonalloanaccountsgood': '1'}

# %% [markdown]
# <br>

# %% [markdown]
# 8. creditaccountsummary

# %%
credit_reports[0]['data']['consumerfullcredit']['creditaccountsummary']
# Out:
# {'rating': '13',
#  'amountarrear': '24,041.00',
#  'amountarrear1': '0.00',
#  'totalaccounts': '7',
#  'totalaccounts1': '0',
#  'lastjudgementdate': '-',
#  'lastjudgementdate1': '-',
#  'totalaccountarrear': '2',
#  'totalaccountarrear1': '0',
#  'totaljudgementamount': '0',
#  'totaloutstandingdebt': '105,435.00',
#  'totaljudgementamount1': '0',
#  'totaloutstandingdebt1': '0.00',
#  'totaldishonouredamount': '0.00',
#  'totalmonthlyinstalment': '77,404.00',
#  'totalnumberofjudgement': '0',
#  'totaldishonouredamount1': '0.00',
#  'totalmonthlyinstalment1': '0.00',
#  'totalnumberofjudgement1': '0',
#  'totalnumberofdishonoured': '0',
#  'totalnumberofdishonoured1': '0',
#  'totalaccountingodcondition': '0',
#  'totalaccountingodcondition1': '0'}

# %% [markdown]
# <br>

# %% [markdown]
# 9. enquirydetails

# %%
credit_reports[0]['data']['consumerfullcredit']['enquirydetails']
# Out:
# {'productid': '45',
#  'matchingrate': '90',
#  'subscriberenquiryengineid': '5012874225',
#  'subscriberenquiryresultid': '6381470'}

# %% [markdown]
# <br>

# %% [markdown]
# 10. enquiryhistorytop

# %%
credit_reports[0]['data']['consumerfullcredit']['enquiryhistorytop']
# Out:
# [{'daterequested': '06/08/2020 18:05:36',
#   'enquiryreason': 'Credit scoring of the client by credit bureau',
#   'subscribername': 'CDL - Credit Direct API',
#   'subscriberenquiryresultid': '6050316'},
#  {'daterequested': '01/08/2020 06:59:09',
#   'enquiryreason': 'Credit scoring of the client by credit bureau',
#   'subscribername': 'CDL - Credit Direct API',
#   'subscriberenquiryresultid': '5983396'},
#  {'daterequested': '08/07/2020 15:58:44',
#   'enquiryreason': 'application of existing credit by a borrower',
#   'subscribername': 'NewEdge Finance Limited  - transsnet',
#   'subscriberenquiryresultid': '5680296'},
#  {'daterequested': '03/07/2020 22:58:39',
#   'enquiryreason': 'Credit scoring of the client by credit bureau',
#   'subscribername': 'CDL - Credit Direct API',
#   'subscriberenquiryresultid': '5637826'},
#  {'daterequested': '04/06/2020 07:55:58',
#   'enquiryreason': 'Credit scoring of the client by credit bureau',
#   'subscribername': 'CDL - Credit Direct API',
#   'subscriberenquiryresultid': '5316386'},
#  {'daterequested': '17/04/2020 07:27:02',
#   'enquiryreason': 'Credit scoring of the client by credit bureau',
#   'subscribername': 'CDL - Credit Direct API',
#   'subscriberenquiryresultid': '4970915'},
#  {'daterequested': '13/04/2020 00:12:08',
#   'enquiryreason': 'Credit scoring of the client by credit bureau',
#   'subscribername': 'CDL - Credit Direct API',
#   'subscriberenquiryresultid': '4938136'},
#  {'daterequested': '28/03/2020 21:54:03',
#   'enquiryreason': 'Credit scoring of the client by credit bureau',
#   'subscribername': 'CDL - Credit Direct API',
#   'subscriberenquiryresultid': '4878437'},
#  {'daterequested': '26/03/2020 10:43:57',
#   'enquiryreason': 'Credit scoring of the client by credit bureau',
#   'subscribername': 'CDL - Credit Direct API',
#   'subscriberenquiryresultid': '4860495'},
#  {'daterequested': '25/03/2020 04:19:05',
#   'enquiryreason': 'Credit scoring of the client by credit bureau',
#   'subscribername': 'CDL - Credit Direct API',
#   'subscriberenquiryresultid': '4846440'},
#  {'daterequested': '25/03/2020 04:17:17',
#   'enquiryreason': 'Credit scoring of the client by credit bureau',
#   'subscribername': 'CDL - Credit Direct API',
#   'subscriberenquiryresultid': '4846436'},
#  {'daterequested': '20/03/2020 07:53:56',
#   'enquiryreason': 'Credit scoring of the client by credit bureau',
#   'subscribername': 'CDL - Credit Direct API',
#   'subscriberenquiryresultid': '4804544'},
#  {'daterequested': '12/03/2020 09:32:20',
#   'enquiryreason': 'Credit scoring of the client by credit bureau',
#   'subscribername': 'CDL - Credit Direct API',
#   'subscriberenquiryresultid': '4709811'},
#  {'daterequested': '28/01/2020 02:39:34',
#   'enquiryreason': 'Credit scoring of the client by credit bureau',
#   'subscribername': 'CDL - Credit Direct API',
#   'subscriberenquiryresultid': '4285341'},
#  {'daterequested': '26/01/2020 19:16:17',
#   'enquiryreason': 'Credit scoring of the client by credit bureau',
#   'subscribername': 'CDL - Credit Direct API',
#   'subscriberenquiryresultid': '4275291'}]

# %% [markdown]
# <br>

# %% [markdown]
# 11. accountmonthlypaymenthistory

# %%
credit_reports[0]['data']['consumerfullcredit']['accountmonthlypaymenthistory']
# Out:
# [{'m01': '#',
#   'm02': '3',
#   'm03': '0',
#   'm04': '0',
#   'm05': '0',
#   'm06': '0',
#   'm07': '36',
#   'm08': '36',
#   'm09': '0',
#   'm10': '31',
#   'm11': '0',
#   'm12': '9',
#   'm13': '1',
#   'm14': '0',
#   'm15': '0',
#   'm16': '3',
#   'm17': '5',
#   'm18': '0',
#   'm19': '4',
#   'm20': '4',
#   'm21': '1',
#   'm22': '0',
#   'm23': '4',
#   'm24': '3',
#   'header': 'Details of Credit Agreement with "First City Monument Bank Ltd Lagos" for Account Number: 0324562636176001',
#   'currency': 'NGN',
#   'accountno': '0324562636176001',
#   'tablename': 'Consumer24MonthlyPayment',
#   'closeddate': '01/11/2020',
#   'accountnote': None,
#   'displaytext': 'Consumer 24 Monthly Payment',
#   'loanduration': '1170 Day(s)',
#   'subaccountno': None,
#   'accountstatus': 'Open',
#   'amountoverdue': '22,441.39',
#   'subscribername': 'First City Monument Bank Ltd Lagos',
#   'lastpaymentdate': '01/08/2020',
#   'lastupdateddate': '07/08/2020',
#   'currentbalanceamt': '82,733.58',
#   'dateaccountopened': '15/01/2016',
#   'openingbalanceamt': '814,700.00',
#   'performancestatus': 'Performing',
#   'subscribertypeind': 'C',
#   'indicatordescription': 'Personal secured loan',
#   'monthlyinstalmentamt': '24,368.39',
#   'repaymentfrequencycode': 'Monthly'},
#  {'m01': '#',
#   'm02': '#',
#   'm03': '#',
#   'm04': '#',
#   'm05': '#',
#   'm06': '#',
#   'm07': '#',
#   'm08': '#',
#   'm09': '#',
#   'm10': '#',
#   'm11': '#',
#   'm12': '#',
#   'm13': '#',
#   'm14': '#',
#   'm15': '#',
#   'm16': '#',
#   'm17': '#',
#   'm18': '#',
#   'm19': '#',
#   'm20': '#',
#   'm21': '#',
#   'm22': '#',
#   'm23': '#',
#   'm24': '#',
#   'header': 'Details of Credit Agreement with "First City Monument Bank Ltd Lagos" for Account Number: 0324602636176001',
#   'currency': 'NGN',
#   'accountno': '0324602636176001',
#   'tablename': 'Consumer24MonthlyPayment',
#   'closeddate': '30/11/2019',
#   'accountnote': None,
#   'displaytext': 'Consumer 24 Monthly Payment',
#   'loanduration': '59 Day(s)',
#   'subaccountno': None,
#   'accountstatus': 'Closed',
#   'amountoverdue': '0.00',
#   'subscribername': 'First City Monument Bank Ltd Lagos',
#   'lastpaymentdate': '04/05/2015',
#   'lastupdateddate': '08/08/2017',
#   'currentbalanceamt': '0.00',
#   'dateaccountopened': '28/08/2014',
#   'openingbalanceamt': '704,000.00',
#   'performancestatus': 'Performing',
#   'subscribertypeind': 'C',
#   'indicatordescription': 'Installment account',
#   'monthlyinstalmentamt': '17,036.09',
#   'currentbalancedebitind': 'C',
#   'repaymentfrequencycode': 'Monthly'},
#  {'m01': '#',
#   'm02': '#',
#   'm03': '#',
#   'm04': '#',
#   'm05': '#',
#   'm06': '#',
#   'm07': '#',
#   'm08': '#',
#   'm09': '#',
#   'm10': '#',
#   'm11': '#',
#   'm12': '#',
#   'm13': '#',
#   'm14': '#',
#   'm15': '#',
#   'm16': '#',
#   'm17': '#',
#   'm18': '#',
#   'm19': '#',
#   'm20': '#',
#   'm21': '#',
#   'm22': '#',
#   'm23': '#',
#   'm24': '#',
#   'header': 'Details of Credit Agreement with "First City Monument Bank Ltd Lagos" for Account Number: 2150224012',
#   'currency': 'NGN',
#   'accountno': '2150224012',
#   'tablename': 'Consumer24MonthlyPayment',
#   'accountnote': None,
#   'displaytext': 'Consumer 24 Monthly Payment',
#   'loanduration': 'Not Available',
#   'subaccountno': None,
#   'accountstatus': 'WrittenOff',
#   'amountoverdue': '1,478.37',
#   'subscribername': 'First City Monument Bank Ltd Lagos',
#   'lastupdateddate': '01/03/2018',
#   'currentbalanceamt': '938.00',
#   'dateaccountopened': '09/05/2013',
#   'openingbalanceamt': '0.00',
#   'performancestatus': 'Performing',
#   'subscribertypeind': 'C',
#   'indicatordescription': 'Overdraft',
#   'currentbalancedebitind': 'D',
#   'repaymentfrequencycode': 'Bullet'},
#  {'m01': '#',
#   'm02': '#',
#   'm03': '#',
#   'm04': '#',
#   'm05': '#',
#   'm06': '#',
#   'm07': '#',
#   'm08': '#',
#   'm09': '#',
#   'm10': '#',
#   'm11': '#',
#   'm12': '#',
#   'm13': '#',
#   'm14': '#',
#   'm15': '#',
#   'm16': '#',
#   'm17': '#',
#   'm18': '#',
#   'm19': '#',
#   'm20': '#',
#   'm21': '#',
#   'm22': '#',
#   'm23': '#',
#   'm24': '#',
#   'header': 'Details of Credit Agreement with "First City Monument Bank Ltd Lagos" for Account Number: 2636176011',
#   'currency': 'NGN',
#   'accountno': '2636176011',
#   'tablename': 'Consumer24MonthlyPayment',
#   'accountnote': None,
#   'displaytext': 'Consumer 24 Monthly Payment',
#   'loanduration': 'Not Available',
#   'subaccountno': None,
#   'accountstatus': None,
#   'amountoverdue': '122.31',
#   'subscribername': 'First City Monument Bank Ltd Lagos',
#   'lastupdateddate': '23/08/2016',
#   'currentbalanceamt': '20,695.64',
#   'dateaccountopened': '12/05/2014',
#   'openingbalanceamt': '0.00',
#   'performancestatus': 'Performing',
#   'subscribertypeind': 'C',
#   'indicatordescription': 'Overdraft',
#   'currentbalancedebitind': 'D',
#   'repaymentfrequencycode': 'Bullet'},
#  {'m01': '#',
#   'm02': '0',
#   'm03': '0',
#   'm04': '0',
#   'm05': '0',
#   'm06': '0',
#   'm07': '0',
#   'm08': '0',
#   'm09': '0',
#   'm10': '0',
#   'm11': '0',
#   'm12': '0',
#   'm13': '0',
#   'm14': '0',
#   'm15': '0',
#   'm16': '0',
#   'm17': '0',
#   'm18': '0',
#   'm19': '0',
#   'm20': '0',
#   'm21': '0',
#   'm22': '0',
#   'm23': '0',
#   'm24': '0',
#   'header': 'Details of Credit Agreement with "First City Monument Bank Ltd Lagos" for Account Number: 2636176028',
#   'currency': 'NGN',
#   'accountno': '2636176028',
#   'tablename': 'Consumer24MonthlyPayment',
#   'closeddate': '21/12/2099',
#   'accountnote': None,
#   'displaytext': 'Consumer 24 Monthly Payment',
#   'loanduration': '5843 Day(s)',
#   'subaccountno': None,
#   'accountstatus': 'Open',
#   'amountoverdue': '0.00',
#   'subscribername': 'First City Monument Bank Ltd Lagos',
#   'lastpaymentdate': '16/07/2020',
#   'lastupdateddate': '07/08/2020',
#   'currentbalanceamt': '42,458.57',
#   'dateaccountopened': '20/12/2015',
#   'openingbalanceamt': '50,479.98',
#   'performancestatus': 'Performing',
#   'subscribertypeind': 'C',
#   'indicatordescription': 'Personal Credit Card Loan',
#   'repaymentfrequencycode': 'Not Available'},
#  {'m01': '#',
#   'm02': '#',
#   'm03': '0',
#   'm04': '#',
#   'm05': '0',
#   'm06': '#',
#   'm07': '#',
#   'm08': '#',
#   'm09': '#',
#   'm10': '#',
#   'm11': '#',
#   'm12': '#',
#   'm13': '#',
#   'm14': '#',
#   'm15': '#',
#   'm16': '#',
#   'm17': '#',
#   'm18': '#',
#   'm19': '#',
#   'm20': '#',
#   'm21': '#',
#   'm22': '#',
#   'm23': '#',
#   'm24': '#',
#   'header': 'Details of Credit Agreement with "MyCredit Invest" for Account Number: 118908402',
#   'currency': 'NGN',
#   'accountno': '118908402',
#   'tablename': 'Consumer24MonthlyPayment',
#   'closeddate': '14/10/2019',
#   'accountnote': None,
#   'displaytext': 'Consumer 24 Monthly Payment',
#   'loanduration': '31 Day(s)',
#   'subaccountno': None,
#   'accountstatus': 'Open',
#   'amountoverdue': '0.00',
#   'subscribername': 'MyCredit Invest',
#   'lastpaymentdate': '23/10/2019',
#   'lastupdateddate': '20/08/2020',
#   'currentbalanceamt': '0.00',
#   'dateaccountopened': '13/09/2019',
#   'openingbalanceamt': '20,000.00',
#   'performancestatus': 'Performing',
#   'subscribertypeind': 'E',
#   'indicatordescription': 'Personal fixed term loan',
#   'monthlyinstalmentamt': '24,000.00',
#   'currentbalancedebitind': None,
#   'repaymentfrequencycode': 'Monthly'},
#  {'m01': '#',
#   'm02': '#',
#   'm03': '#',
#   'm04': '#',
#   'm05': '#',
#   'm06': '#',
#   'm07': '#',
#   'm08': '#',
#   'm09': '#',
#   'm10': '0',
#   'm11': '#',
#   'm12': '#',
#   'm13': '#',
#   'm14': '#',
#   'm15': '#',
#   'm16': '0',
#   'm17': '#',
#   'm18': '#',
#   'm19': '#',
#   'm20': '#',
#   'm21': '#',
#   'm22': '#',
#   'm23': '#',
#   'm24': '#',
#   'header': 'Details of Credit Agreement with "MyCredit Invest" for Account Number: 1204665',
#   'currency': 'NGN',
#   'accountno': '1204665',
#   'tablename': 'Consumer24MonthlyPayment',
#   'closeddate': '25/11/2019',
#   'accountnote': None,
#   'displaytext': 'Consumer 24 Monthly Payment',
#   'loanduration': 'Not Available',
#   'subaccountno': None,
#   'accountstatus': None,
#   'amountoverdue': '0.00',
#   'subscribername': 'MyCredit Invest',
#   'lastupdateddate': '24/12/2019',
#   'currentbalanceamt': '0.00',
#   'dateaccountopened': '25/10/2019',
#   'openingbalanceamt': '10,000.00',
#   'performancestatus': 'Performing',
#   'subscribertypeind': 'E',
#   'monthlyinstalmentamt': '12,000.00',
#   'repaymentfrequencycode': 'Not Available'}]

# %% [markdown]
# <br>

# %% [markdown]
# 12. accountmonthlypaymenthistoryheader

# %%
credit_reports[0]['data']['consumerfullcredit']['accountmonthlypaymenthistoryheader']
# Out:
# {'mh01': '2020\nAUG',
#  'mh02': '2020\nJUL',
#  'mh03': '2020\nJUN',
#  'mh04': '2020\nMAY',
#  'mh05': '2020\nAPR',
#  'mh06': '2020\nMAR',
#  'mh07': '2020\nFEB',
#  'mh08': '2020\nJAN',
#  'mh09': '2019\nDEC',
#  'mh10': '2019\nNOV',
#  'mh11': '2019\nOCT',
#  'mh12': '2019\nSEP',
#  'mh13': '2019\nAUG',
#  'mh14': '2019\nJUL',
#  'mh15': '2019\nJUN',
#  'mh16': '2019\nMAY',
#  'mh17': '2019\nAPR',
#  'mh18': '2019\nMAR',
#  'mh19': '2019\nFEB',
#  'mh20': '2019\nJAN',
#  'mh21': '2018\nDEC',
#  'mh22': '2018\nNOV',
#  'mh23': '2018\nOCT',
#  'mh24': '2018\nSEP',
#  'company': 'Company',
#  'tablename': 'Consumer24MonthlyPaymentHeader',
#  'displaytext': 'Consumer 24 Monthly Payment Header'}

# %% [markdown]
# <br>

# %% [markdown]
# 13. subjectlist

# %%
credit_reports[0]['data']['consumerfullcredit']['subjectlist']
# Out:
# {'reference': '12876566', 'consumerid': '17628566', 'searchoutput': 'XXX '}

# %% [markdown]
# <br>

# %% [markdown]
# 14. creditagreementsummary

# %%
credit_reports[0]['data']['consumerfullcredit']['creditagreementsummary']
# Out:
# [{'currency': 'NGN',
#   'accountno': '0324562636176001',
#   'closeddate': '01/11/2020',
#   'loanduration': '1170',
#   'subaccountno': None,
#   'accountstatus': 'Open',
#   'amountoverdue': '22,441.39',
#   'subscribername': 'First City Monument Bank Ltd Lagos',
#   'lastupdateddate': '07/08/2020',
#   'instalmentamount': '24,368.39',
#   'currentbalanceamt': '82,733.58',
#   'dateaccountopened': '15/01/2016',
#   'openingbalanceamt': '814,700.00',
#   'performancestatus': 'Performing',
#   'repaymentfrequency': 'Monthly',
#   'indicatordescription': 'Personal secured loan'},
#  {'currency': 'NGN',
#   'accountno': '0324602636176001',
#   'closeddate': '30/11/2019',
#   'loanduration': '59',
#   'subaccountno': None,
#   'accountstatus': 'Closed',
#   'amountoverdue': '0.00',
#   'subscribername': 'First City Monument Bank Ltd Lagos',
#   'lastupdateddate': '08/08/2017',
#   'instalmentamount': '17,036.09',
#   'currentbalanceamt': '0.00',
#   'dateaccountopened': '28/08/2014',
#   'openingbalanceamt': '704,000.00',
#   'performancestatus': 'Performing',
#   'repaymentfrequency': 'Monthly',
#   'indicatordescription': 'Installment account',
#   'currentbalancedebitind': 'C'},
#  {'currency': 'NGN',
#   'accountno': '118908402',
#   'closeddate': '14/10/2019',
#   'loanduration': '31',
#   'subaccountno': None,
#   'accountstatus': 'Open',
#   'amountoverdue': '0.00',
#   'subscribername': 'MyCredit Invest',
#   'lastupdateddate': '20/08/2020',
#   'instalmentamount': '24,000.00',
#   'currentbalanceamt': '0.00',
#   'dateaccountopened': '13/09/2019',
#   'openingbalanceamt': '20,000.00',
#   'performancestatus': 'Performing',
#   'repaymentfrequency': 'Monthly',
#   'indicatordescription': 'Personal fixed term loan',
#   'currentbalancedebitind': None},
#  {'currency': 'NGN',
#   'accountno': '1204665',
#   'closeddate': '25/11/2019',
#   'subaccountno': None,
#   'accountstatus': None,
#   'amountoverdue': '0.00',
#   'subscribername': 'MyCredit Invest',
#   'lastupdateddate': '24/12/2019',
#   'instalmentamount': '12,000.00',
#   'currentbalanceamt': '0.00',
#   'dateaccountopened': '25/10/2019',
#   'openingbalanceamt': '10,000.00',
#   'performancestatus': 'Performing',
#   'repaymentfrequency': 'Not Available'},
#  {'currency': 'NGN',
#   'accountno': '2150224012',
#   'loanduration': '0',
#   'subaccountno': None,
#   'accountstatus': 'WrittenOff',
#   'amountoverdue': '1,478.37',
#   'subscribername': 'First City Monument Bank Ltd Lagos',
#   'lastupdateddate': '01/03/2018',
#   'currentbalanceamt': '938.00',
#   'dateaccountopened': '09/05/2013',
#   'openingbalanceamt': '0.00',
#   'performancestatus': 'Performing',
#   'repaymentfrequency': 'Bullet',
#   'indicatordescription': 'Overdraft',
#   'currentbalancedebitind': 'D'},
#  {'currency': 'NGN',
#   'accountno': '2636176011',
#   'loanduration': '0',
#   'subaccountno': None,
#   'accountstatus': None,
#   'amountoverdue': '122.31',
#   'subscribername': 'First City Monument Bank Ltd Lagos',
#   'lastupdateddate': '23/08/2016',
#   'currentbalanceamt': '20,695.64',
#   'dateaccountopened': '12/05/2014',
#   'openingbalanceamt': '0.00',
#   'performancestatus': 'Performing',
#   'repaymentfrequency': 'Bullet',
#   'indicatordescription': 'Overdraft',
#   'currentbalancedebitind': 'D'},
#  {'currency': 'NGN',
#   'accountno': '2636176028',
#   'closeddate': '21/12/2099',
#   'loanduration': '5843',
#   'subaccountno': None,
#   'accountstatus': 'Open',
#   'amountoverdue': '0.00',
#   'subscribername': 'First City Monument Bank Ltd Lagos',
#   'lastupdateddate': '07/08/2020',
#   'currentbalanceamt': '42,458.57',
#   'dateaccountopened': '20/12/2015',
#   'openingbalanceamt': '50,479.98',
#   'performancestatus': 'Performing',
#   'repaymentfrequency': 'Not Available',
#   'indicatordescription': 'Personal Credit Card Loan'}]

# %% [markdown]
# <br>

# %% [markdown]
# ## Function to extract necessary information

# %%
def extract_summary(report):
    credit_data = report['data']['consumerfullcredit']

    risk_summary_data={}

    # Firstly, we identify relevent information from the personal details summary
    # 1. gender
    # 2. date of birth
    # 3. nationality
    # 4. dependants
    personaldetails_relevant_info = ["gender","birthdate","nationality","dependants"]

    # Extract the relevant information from credit data
    for info in personaldetails_relevant_info:
      risk_summary_data[info]=credit_data["personaldetailssummary"][info]

    # 2. Employment history
    # Next, extracting information relating to the employment history
    # extract the list of occupation
    occupations = []
    for occupation in credit_data['employmenthistory']:
      occupations.append(occupation['occupation'])

    risk_summary_data['oldest occupation']=occupations[0]  # get the oldest  occupation
    risk_summary_data['newest occupation']=occupations[-1] # get the newest  occupation


    # 3. Telephon history
    #  Here, we compute how long the user has used the phone numbers : oldest and newest

    telephonehistory_home = []
    telephonehistory_mobile = []
    today = datetime.today()
    telephonehistory_home_duration=[]
    telephonehistory_mobile_duration=[]

    for s in credit_data['telephonehistory']:
        if 'homenoupdatedondate' in s:
            telephonehistory_home.append(s['homenoupdatedondate'])
            x=datetime.strptime(s['homenoupdatedondate'],'%d/%m/%Y')
            telephonehistory_home_duration.append((today-x).days)

        if 'mobilenoupdatedondate' in s:
            telephonehistory_mobile.append(s['mobilenoupdatedondate'])

            x=datetime.strptime(s['mobilenoupdatedondate'],'%d/%m/%Y')
            telephonehistory_mobile_duration.append((today-x).days)

    risk_summary_data['no_mobilenoupdatedondate'] = len(telephonehistory_mobile)

    risk_summary_data['no_homenoupdatedondate'] = len(telephonehistory_home)

    risk_summary_data['telephonehistory_mobile_duration_max'] = max(telephonehistory_home_duration) if len(telephonehistory_home_duration) else None

    risk_summary_data['telephonehistory_mobile_duration_min'] = min(telephonehistory_mobile_duration) if len(telephonehistory_mobile_duration) else None

    risk_summary_data['telephonehistory_home_duration_max'] = max(telephonehistory_home_duration) if len(telephonehistory_home_duration) else None

    risk_summary_data['telephonehistory_home_duration_min'] = min(telephonehistory_home_duration) if len(telephonehistory_home_duration) else None

    # 4. Gaurator count

    risk_summary_data['guarantor_counts_guarantorssecured']=credit_data['guarantorcount']['guarantorssecured']
    risk_summary_data['guarantor_counts_accounts']=credit_data['guarantorcount']['accounts']

    # 5. Gaurantor details
    # Here, we check if the gaurantor details is available
    risk_summary_data['Is_gaurantor_firstname_available']=credit_data['guarantordetails']['guarantorfirstname'] is not None

    risk_summary_data['Is_gaurantor_phone_number_available']=credit_data['guarantordetails']['guarantormobiletelephone'] is not None \
                                                              or credit_data['guarantordetails']['guarantorhometelephone'] is not None \
                                                              or credit_data['guarantordetails']['guarantorworktelephone'] is not None


    # 6. delinquency information
    risk_summary_data['monthsinarrears']=credit_data['deliquencyinformation']['monthsinarrears']


    # 7.Account Rating
    for rating in credit_data['accountrating']:
        risk_summary_data[rating]=float(credit_data['accountrating'][rating])

    # 8. creditaccountsummary
    for rating in credit_data['creditaccountsummary']:
        try:
          risk_summary_data[rating]=float(credit_data['creditaccountsummary'][rating].replace(',',''))
        except:
          risk_summary_data[rating]=None

    #9. enquirydetails
    risk_summary_data['matchingrate']=credit_data['enquirydetails']['matchingrate']

    # 10. enquiryhistorytop
    risk_summary_data['No_credit_report_requested']=len(credit_data['enquiryhistorytop'])

    # 11. accountmonthlypaymenthistory

    # loan duration
    durations=[]
    for summary in credit_data['accountmonthlypaymenthistory']:
        duration = summary['loanduration']
        if duration=="Not Available":
            continue
        durations.append(int(duration.split()[0]))


    risk_summary_data['max_loandurations']=max(durations)
    risk_summary_data['mean_loandurations']=sum(durations)/len(durations)
    risk_summary_data['min_loandurations']=min(durations)

    # current balance amount
    amounts=[]
    for summary in credit_data['accountmonthlypaymenthistory']:
        amount = summary['currentbalanceamt']

        amounts.append(float(amount.replace(',','')))

    risk_summary_data['max_currentbalanceamt']=max(amounts)
    risk_summary_data['mean_currentbalanceamt']=sum(amounts)/len(amounts)
    risk_summary_data['min_currentbalanceamt']=min(amounts)

    # opening balance amount
    amounts=[]
    for summary in credit_data['accountmonthlypaymenthistory']:
        amount = summary['openingbalanceamt']

        amounts.append(float(amount.replace(',','')))

    risk_summary_data['max_openingbalanceamt']=max(amounts)
    risk_summary_data['mean_openingbalanceamt']=sum(amounts)/len(amounts)
    risk_summary_data['min_openingbalanceamt']=min(amounts)

    # amount overdue
    amounts=[]
    for summary in credit_data['accountmonthlypaymenthistory']:
        if 'amountoverdue' not in summary:
            continue
        amount = summary['amountoverdue']

        amounts.append(float(amount.replace(',','')))

    risk_summary_data['max_amountoverdue']=max(amounts)
    risk_summary_data['mean_amountoverdue']=sum(amounts)/len(amounts)
    risk_summary_data['min_amountoverdue']=min(amounts)

    # age of bank account open

    ages=[]
    for summary in credit_data['accountmonthlypaymenthistory']:
        accdate = datetime.strptime(summary['dateaccountopened'],'%d/%m/%Y')
        age=(today-accdate).days

        ages.append(age)
    
    
    risk_summary_data['max_age_in_days_account']=max(ages)
    risk_summary_data['mean_age_in_days_account']=sum(ages)/len(ages)
    risk_summary_data['min_age_in_days_account']=min(ages)
    
    # monthly delinquency report from 24 months payment
    
    # we compute the percentage of payment made on time for every 24 months
    percentage_payment_made_ontime=[]
    for summary in credit_data['accountmonthlypaymenthistory']:
        paymentontime=0
        counter=0
        for i in range(1,25): # loop through the 24 months
            if i<10:
                if summary['m0'+str(i)]=='0':
                    paymentontime+=1
                if summary['m0'+str(i)]!='#':
                    counter+=1
            else:
                if summary['m'+str(i)]=='0':
                    paymentontime+=1
                if summary['m'+str(i)]!='#':
                    counter+=1
                    
        p=100*paymentontime/counter if counter>0 else np.nan
        percentage_payment_made_ontime.append(p)
        
    
    risk_summary_data['mean_percentage_paymentontime']=np.nanmean(percentage_payment_made_ontime)
    
    return risk_summary_data

# %%
# Convert to DataFrame
data_extracted = [extract_summary(report) for report in credit_reports]
df = pd.DataFrame(data_extracted)

# Display the DataFrame
print(df.head())
# Out:
#    gender   birthdate nationality dependants oldest occupation  \
# 0    Male  06/05/1991     Nigeria          0   PUBLIC SERVANTS
# 1  Female  30/11/1985     Nigeria          0     CIVIL SERVANT
# 2  Female  14/07/1983     Nigeria          0           STUDENT
#
#   newest occupation  no_mobilenoupdatedondate  no_homenoupdatedondate  \
# 0   PUBLIC SERVANTS                         0                       3
# 1            DOCTOR                         2                       3
# 2           STUDENT                         0                       0
#
#    telephonehistory_mobile_duration_max  telephonehistory_mobile_duration_min  \
# 0                                3549.0                                   NaN
# 1                                3824.0                                3136.0
# 2                                   NaN                                   NaN
#
#    ...  max_openingbalanceamt  mean_openingbalanceamt min_openingbalanceamt  \
# 0  ...               814700.0           228454.282857                   0.0
# 1  ...               217000.0            36564.705882                   0.0
# 2  ...              1080936.0           363645.333333                   0.0
#
#   max_amountoverdue  mean_amountoverdue  min_amountoverdue  \
# 0          22441.39         3434.581429                0.0
# 1              0.00            0.000000                0.0
# 2          12000.00         4000.000000                0.0
#
#   max_age_in_days_account  mean_age_in_days_account  min_age_in_days_account  \
# 0                    4389               3323.571429                     2029
# 1                    4805               2341.176471                     1749
# 2                    2092               1919.000000                     1749
#
#    mean_percentage_paymentontime
# 0                      85.869565
# 1                      96.060606
# 2                      61.111111
#
# [3 rows x 76 columns]

# %%
df
# Out:
#    gender   birthdate nationality dependants oldest occupation  \
# 0    Male  06/05/1991     Nigeria          0   PUBLIC SERVANTS
# 1  Female  30/11/1985     Nigeria          0     CIVIL SERVANT
# 2  Female  14/07/1983     Nigeria          0           STUDENT
#
#   newest occupation  no_mobilenoupdatedondate  no_homenoupdatedondate  \
# 0   PUBLIC SERVANTS                         0                       3
# 1            DOCTOR                         2                       3
# 2           STUDENT                         0                       0
#
#    telephonehistory_mobile_duration_max  telephonehistory_mobile_duration_min  \
# 0                                3549.0                                   NaN
# 1                                3824.0                                3136.0
# 2                                   NaN                                   NaN
#
#    ...  max_openingbalanceamt  mean_openingbalanceamt min_openingbalanceamt  \
# 0  ...               814700.0           228454.282857                   0.0
# 1  ...               217000.0            36564.705882                   0.0
# 2  ...              1080936.0           363645.333333                   0.0
#
#   max_amountoverdue  mean_amountoverdue  min_amountoverdue  \
# 0          22441.39         3434.581429                0.0
# 1              0.00            0.000000                0.0
# 2          12000.00         4000.000000                0.0
#
#   max_age_in_days_account  mean_age_in_days_account  min_age_in_days_account  \
# 0                    4389               3323.571429                     2029
# 1                    4805               2341.176471                     1749
# 2                    2092               1919.000000                     1749
#
#    mean_percentage_paymentontime
# 0                      85.869565
# 1                      96.060606
# 2                      61.111111
#
# [3 rows x 76 columns]

# %% [markdown]
# #### We further process the dataframe to have only integers and floats , which are needed for machine learning models

# %%
# Compute age from birthdate

df['age']=datetime.today().year-df['birthdate'].str.split('/').str[-1].astype(int)

df.drop('birthdate', axis=1, inplace=True)

# %%
df
# Out:
#    gender nationality dependants oldest occupation newest occupation  \
# 0    Male     Nigeria          0   PUBLIC SERVANTS   PUBLIC SERVANTS
# 1  Female     Nigeria          0     CIVIL SERVANT            DOCTOR
# 2  Female     Nigeria          0           STUDENT           STUDENT
#
#    no_mobilenoupdatedondate  no_homenoupdatedondate  \
# 0                         0                       3
# 1                         2                       3
# 2                         0                       0
#
#    telephonehistory_mobile_duration_max  telephonehistory_mobile_duration_min  \
# 0                                3549.0                                   NaN
# 1                                3824.0                                3136.0
# 2                                   NaN                                   NaN
#
#    telephonehistory_home_duration_max  ...  mean_openingbalanceamt  \
# 0                              3549.0  ...           228454.282857
# 1                              3824.0  ...            36564.705882
# 2                                 NaN  ...           363645.333333
#
#   min_openingbalanceamt max_amountoverdue  mean_amountoverdue  \
# 0                   0.0          22441.39         3434.581429
# 1                   0.0              0.00            0.000000
# 2                   0.0          12000.00         4000.000000
#
#    min_amountoverdue max_age_in_days_account  mean_age_in_days_account  \
# 0                0.0                    4389               3323.571429
# 1                0.0                    4805               2341.176471
# 2                0.0                    2092               1919.000000
#
#    min_age_in_days_account  mean_percentage_paymentontime  age
# 0                     2029                      85.869565   34
# 1                     1749                      96.060606   40
# 2                     1749                      61.111111   42
#
# [3 rows x 76 columns]

# %%
# Encode the categorical dataest as dummies
df=pd.get_dummies(df, columns=["gender","nationality","oldest occupation", "newest occupation"], drop_first=True)

# %% [markdown]
# <br>

# %% [markdown]
# #### Finally, we obtain the features that is ready for machine learning model inputs

# %%
df
# Out:
#   dependants  no_mobilenoupdatedondate  no_homenoupdatedondate  \
# 0          0                         0                       3
# 1          0                         2                       3
# 2          0                         0                       0
#
#    telephonehistory_mobile_duration_max  telephonehistory_mobile_duration_min  \
# 0                                3549.0                                   NaN
# 1                                3824.0                                3136.0
# 2                                   NaN                                   NaN
#
#    telephonehistory_home_duration_max  telephonehistory_home_duration_min  \
# 0                              3549.0                              3324.0
# 1                              3824.0                              3324.0
# 2                                 NaN                                 NaN
#
#   guarantor_counts_guarantorssecured guarantor_counts_accounts  \
# 0                                  0                         0
# 1                                  0                         0
# 2                                  0                         0
#
#    Is_gaurantor_firstname_available  ...  max_age_in_days_account  \
# 0                             False  ...                     4389
# 1                             False  ...                     4805
# 2                             False  ...                     2092
#
#   mean_age_in_days_account  min_age_in_days_account  \
# 0              3323.571429                     2029
# 1              2341.176471                     1749
# 2              1919.000000                     1749
#
#    mean_percentage_paymentontime  age  gender_Male  \
# 0                      85.869565   34            1
# 1                      96.060606   40            0
# 2                      61.111111   42            0
#
#    oldest occupation_PUBLIC SERVANTS  oldest occupation_STUDENT  \
# 0                                  1                          0
# 1                                  0                          0
# 2                                  0                          1
#
#    newest occupation_PUBLIC SERVANTS  newest occupation_STUDENT
# 0                                  1                          0
# 1                                  0                          0
# 2                                  0                          1
#
# [3 rows x 77 columns]
